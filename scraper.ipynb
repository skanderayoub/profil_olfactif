# %%
import requests
from bs4 import BeautifulSoup
import time
import pandas as pd

# Configuration
BASE_URL = "https://www.olfastory.com"
USER_AGENT = "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36"
HEADERS = {"User-Agent": USER_AGENT}

# Target categories (based on provided HTML and previous context)
CATEGORIES = ["/parfum/homme", "/parfum/femme", "/parfums/mixte"]

# %%
# List to store all perfume data
perfumes_data = []

# Function to extract details from a perfume's main page
def extract_perfume_details(perfume_url):
    try:
        response = requests.get(perfume_url, headers=HEADERS)
        if response.status_code != 200:
            print(f"Erreur {response.status_code} pour {perfume_url}")
            return {
                "concentration": "Inconnu",
                "facettes": "Inconnu",
                "date_creation": "Inconnu",
                "parfumeurs": "Inconnu",
                "description_title": "Inconnu",
                "description_text": "Inconnu"
            }

        soup = BeautifulSoup(response.text, "html.parser")
        details = {}

        # Find the details section
        details_section = soup.find("div", class_="c-list__group")
        if details_section:
            # Concentration
            concentration_tag = details_section.find("div", class_="c-list__label", string="Concentration")
            if concentration_tag:
                concentration = concentration_tag.find_next("div", class_="c-list__content").find("li")
                details["concentration"] = concentration.text.strip() if concentration else "Inconnu"
            else:
                details["concentration"] = "Inconnu"

            # Facettes
            facettes_tag = details_section.find("div", class_="c-list__label", string="Facettes")
            if facettes_tag:
                facettes = [li.text.strip() for li in facettes_tag.find_next("div", class_="c-list__content").find_all("li")]
                details["facettes"] = ";".join(facettes) if facettes else "Inconnu"
            else:
                details["facettes"] = "Inconnu"

            # Date de création
            date_tag = details_section.find("div", class_="c-list__label", string="Date de création")
            if date_tag:
                date = date_tag.find_next("div", class_="c-list__content").find("li")
                details["date_creation"] = date.text.strip() if date else "Inconnu"
            else:
                details["date_creation"] = "Inconnu"

            # Parfumeurs
            parfumeurs_tag = details_section.find("div", class_="c-list__label", string="Parfumeurs")
            if parfumeurs_tag:
                parfumeurs = [li.text.strip() for li in parfumeurs_tag.find_next("div", class_="c-list__content").find_all("li")]
                details["parfumeurs"] = ";".join(parfumeurs) if parfumeurs else "Inconnu"
            else:
                details["parfumeurs"] = "Inconnu"
        else:
            details.update({
                "concentration": "Inconnu",
                "facettes": "Inconnu",
                "date_creation": "Inconnu",
                "parfumeurs": "Inconnu"
            })

        # Description (title and text)
        content_section = soup.find("div", class_="c-tab__content")
        if content_section:
            # Try h2 or h3 for title
            title_tag = content_section.find(["h2", "h3"])
            details["description_title"] = title_tag.text.strip() if title_tag else "Inconnu"

            # Find the description text (first <p> after title or within content)
            description_tag = content_section.find("p", recursive=True)
            details["description_text"] = description_tag.text.strip() if description_tag else "Inconnu"
        else:
            details["description_title"] = "Inconnu"
            details["description_text"] = "Inconnu"

        return details

    except Exception as e:
        print(f"Erreur lors de l'accès à {perfume_url}: {e}")
        return {
            "concentration": "Inconnu",
            "facettes": "Inconnu",
            "date_creation": "Inconnu",
            "parfumeurs": "Inconnu",
            "description_title": "Inconnu",
            "description_text": "Inconnu"
        }

# Function to extract composition from a perfume's composition page
def extract_composition(composition_url):
    try:
        response = requests.get(composition_url, headers=HEADERS)
        if response.status_code != 200:
            print(f"Erreur {response.status_code} pour {composition_url}")
            return {
                "notes_tete": "Inconnu",
                "notes_coeur": "Inconnu",
                "notes_fond": "Inconnu"
            }

        soup = BeautifulSoup(response.text, "html.parser")
        composition = {}

        # Find all pyramid areas
        pyramid_areas = soup.find_all("div", class_="c-pyramide__area")
        for area in pyramid_areas:
            label = area.find("div", class_="c-pyramide__label")
            if label:
                label_text = label.text.strip()
                notes = [li.text.strip() for li in area.find_all("li")]
                notes_text = ";".join(notes) if notes else "Inconnu"
                if "Notes de tête" in label_text:
                    composition["notes_tete"] = notes_text
                elif "Notes de coeur" in label_text:
                    composition["notes_coeur"] = notes_text
                elif "Notes de fond" in label_text:
                    composition["notes_fond"] = notes_text

        # Ensure all fields are present
        composition.setdefault("notes_tete", "Inconnu")
        composition.setdefault("notes_coeur", "Inconnu")
        composition.setdefault("notes_fond", "Inconnu")

        return composition

    except Exception as e:
        print(f"Erreur lors de l'accès à {composition_url}: {e}")
        return {
            "notes_tete": "Inconnu",
            "notes_coeur": "Inconnu",
            "notes_fond": "Inconnu"
        }

# Function to extract perfumes from a category page
def extract_perfumes(category_url, category_name, page_number):
    try:
        # Construct URL
        if page_number == 0:
            url = category_url
        else:
            url = f"{category_url}?page={page_number - 1}"

        response = requests.get(url, headers=HEADERS)
        if response.status_code != 200:
            print(f"Erreur {response.status_code} pour {url}")
            return False, []

        soup = BeautifulSoup(response.text, "html.parser")
        perfume_cards = soup.find_all("div", class_="c-product__card")
        if not perfume_cards:
            print(f"Aucun parfum trouvé pour {url}")
            return False, []

        print(f"\n=== Parfums de la catégorie : {url} (Page {page_number}) ===\n")
        page_perfumes = []

        for card in perfume_cards:
            perfume = {}

            # Name and Perfume URL
            name_tag = card.find("div", class_="c-product__title").find("a") if card.find("div", class_="c-product__title") else None
            perfume["name"] = name_tag.text.strip() if name_tag else "Inconnu"
            perfume["perfume_url"] = name_tag["href"] if name_tag and "href" in name_tag.attrs else "Inconnu"

            # Brand
            brand_tag = card.find("span", class_="c-product__brand")
            perfume["brand"] = brand_tag.text.strip() if brand_tag else "Inconnu"

            # Type and Year
            details_tag = card.find("div", class_="c-product__details")
            if details_tag:
                details_text = details_tag.text.strip()
                details_parts = details_text.split(" - ")
                perfume["type"] = details_parts[0] if len(details_parts) > 0 else "Inconnu"
                perfume["year"] = details_parts[1] if len(details_parts) > 1 else "Inconnu"
            else:
                perfume["type"] = "Inconnu"
                perfume["year"] = "Inconnu"

            perfume["gender"] = category_name.capitalize()

            # Olfactory Family
            family_tag = card.find("div", class_="c-product__family").find("span") if card.find("div", class_="c-product__family") else None
            perfume["family"] = family_tag.text.strip() if family_tag else "Inconnu"

            # Image URL
            img_tag = card.find("img", class_="lazyload")
            perfume["image_url"] = img_tag["data-src"] if img_tag and "data-src" in img_tag.attrs else "Inconnu"

            # Fetch additional details from perfume page
            if perfume["perfume_url"] != "Inconnu":
                details = extract_perfume_details(perfume["perfume_url"])
                perfume.update(details)

                # Fetch composition from composition page
                composition_url = f"{perfume['perfume_url']}/composition/#o"
                composition = extract_composition(composition_url)
                perfume.update(composition)
            else:
                perfume.update({
                    "concentration": "Inconnu",
                    "facettes": "Inconnu",
                    "date_creation": "Inconnu",
                    "parfumeurs": "Inconnu",
                    "description_title": "Inconnu",
                    "description_text": "Inconnu",
                    "notes_tete": "Inconnu",
                    "notes_coeur": "Inconnu",
                    "notes_fond": "Inconnu"
                })

            # Print perfume data
            print("Parfum trouvé :")
            print(f"  Nom : {perfume['name']}")
            print(f"  URL : {perfume['perfume_url']}")
            print(f"  Marque : {perfume['brand']}")
            print(f"  Type : {perfume['type']}")
            print(f"  Année : {perfume['year']}")
            print(f"  Genre : {perfume['gender']}")
            print(f"  Famille olfactive : {perfume['family']}")
            print(f"  URL de l'image : {perfume['image_url']}")
            print(f"  Concentration : {perfume['concentration']}")
            print(f"  Facettes : {perfume['facettes']}")
            print(f"  Date de création : {perfume['date_creation']}")
            print(f"  Parfumeurs : {perfume['parfumeurs']}")
            print(f"  Titre de description : {perfume['description_title']}")
            print(f"  Texte de description : {perfume['description_text']}")
            print(f"  Notes de tête : {perfume['notes_tete']}")
            print(f"  Notes de cœur : {perfume['notes_coeur']}")
            print(f"  Notes de fond : {perfume['notes_fond']}")
            print("-" * 50)

            page_perfumes.append(perfume)
            time.sleep(1)  # Delay for individual perfume page requests

        # Check for next page
        next_page = soup.find("li", class_="pager-next")  # Adapt selector if needed
        has_next_page = next_page and "disabled" not in next_page.get("class", [])

        return has_next_page, page_perfumes

    except Exception as e:
        print(f"Erreur lors de l'accès à {url}: {e}")
        return False, []

# Main scraping logic
try:
    response = requests.get(BASE_URL, headers=HEADERS)
    if response.status_code != 200:
        print(f"Erreur {response.status_code} pour {BASE_URL}")
        exit()

    soup = BeautifulSoup(response.text, "html.parser")
    category_links = soup.find_all("li", class_="js-equalizer__item c-nav__nosubmenu")
    found_categories = []

    for li in category_links:
        a_tag = li.find("a", href=True)
        if a_tag and a_tag["href"] in CATEGORIES:
            category_href = a_tag["href"]
            found_categories.append(category_href)

    print("\nCatégories trouvées dans le menu de navigation :")
    if found_categories:
        for cat in found_categories:
            print(f"- {cat}")
    else:
        print("Aucune catégorie correspondante trouvée. Utilisation des catégories prédéfinies.")

    categories_to_scrape = found_categories if found_categories else CATEGORIES

    for category in categories_to_scrape:
        full_url = BASE_URL + category
        category_name = category.split("/")[-1]
        page_number = 0

        while True:
            print(f"\nScraping {full_url} (Page {page_number})")
            has_next_page, page_perfumes = extract_perfumes(full_url, category_name, page_number)
            perfumes_data.extend(page_perfumes)

            if not has_next_page:
                break

            page_number += 1
            time.sleep(0.5)  # Delay for category page requests

    # Create DataFrame
    df = pd.DataFrame(perfumes_data)
    if not df.empty:
        columns = [
            "name", "perfume_url", "brand", "type", "year", "gender", "family", "image_url",
            "concentration", "facettes", "date_creation", "parfumeurs",
            "description_title", "description_text",
            "notes_tete", "notes_coeur", "notes_fond"
        ]
        df = df[columns]
        # Save to CSV
        df.to_csv("parfums.csv", index=False, encoding="utf-8")
        # Save to Excel
        df.to_excel("parfums.xlsx", index=False, engine="openpyxl")
        print(f"\nBase de données sauvegardée dans 'parfums.csv' et 'parfums.xlsx' avec {len(df)} parfums.")
    else:
        print("\nAucun parfum extrait. Vérifiez les sélecteurs ou le contenu dynamique.")

except Exception as e:
    print(f"Erreur lors de l'accès à {BASE_URL}: {e}")
# Out:
# Catégories trouvées dans le menu de navigation :
# - /parfum/homme
# - /parfum/femme
# - /parfums/mixte
#
# Scraping https://www.olfastory.com/parfum/homme (Page 0)
#
# === Parfums de la catégorie : https://www.olfastory.com/parfum/homme (Page 0) ===
#
# Parfum trouvé :
#   Nom : Acqua di Giò Profondo
#   URL : https://www.olfastory.com/parfum/acqua-di-gio-profondo-0
#   Marque : Armani
#   Type : Eau de toilette
#   Année : 2025
#   Genre : Homme
#   Famille olfactive : Aromatique
#   URL de l'image : https://www.olfastory.com/sites/www.olfastory.com/files/styles/300x300/public/acqua-di-gio-profondo-eau-de-toilette.jpg?itok=N2WigyFu
#   Concentration : Eau de toilette
#   Facettes : Marine
#   Date de création : 2025
#   Parfumeurs : Alberto Morillas
#   Titre de description : Présentation du parfum
#   Texte de description : Présentation du parfumImmersion dans le bleu profondSortie printemps 2025, cette Eau de Toilette revisite la signature marine d’Armani : plus aérienne que l’édition Parfum, elle retranscrit l’instant où la lumière filtre sous la surface. Conçue par Alberto Morillas, la composition unit fraîcheur, minéralité et élégance italienne.
#   Notes de tête : Cardamome;Citron;Mandarine;Pamplemousse
#   Notes de cœur : Cyprès;Lavandin;Note marine;Sauge sclarée
#   Notes de fond : Musc;Patchouli
# --------------------------------------------------
# Parfum trouvé :
#   Nom : L.12.12 Silver Grey
#   URL : https://www.olfastory.com/parfum/l1212-silver-grey
#   Marque : Lacoste
#   Type : Eau de parfum
#   Année : 2025
#   Genre : Homme
#   Famille olfactive : Fougère
#   URL de l'image : https://www.olfastory.com/sites/www.olfastory.com/files/styles/300x300/public/l1212-silver-grey-lacoste.jpg?itok=cZ-2tL94
#   Concentration : Eau de parfum
#   Facettes : Boisée
#   Date de création : 2025
#   Parfumeurs : Bruno Jovanovic
#   Titre de description : Présentation du parfum Lacoste L.12.12 Silver Grey
#   Texte de description : Présentation du parfum Lacoste L.12.12 Silver GreyADN fougère-boisée sport-chicLancé au printemps 2025, Silver Grey incarne la veine athleisure de Lacoste : un souffle fougère-boisé qui marie mandarine zestée, encens minéral, lavande aromatique et ambrox boisé pour un contraste chaud-froid racé.Inspiration métallique & héritage poloLe flacon gris miroir rappelle la première raquette acier de René Lacoste et réinterprète le fameux « petit piqué » du polo L.12.12, symbole d’élégance décontractée.
#   Notes de tête : Encens;Mandarine
#   Notes de cœur : Géranium;Lavande
#   Notes de fond : Ambroxan;Vétiver
# --------------------------------------------------
# Parfum trouvé :
#   Nom : Original
#   URL : https://www.olfastory.com/parfum/original
#   Marque : Lacoste
#   Type : Extrait
#   Année : 2025
#   Genre : Homme
#   Famille olfactive : Fougère
#   URL de l'image : https://www.olfastory.com/sites/www.olfastory.com/files/styles/300x300/public/lacoste-orignal-pafum.jpg?itok=rijwQRYa
#   Concentration : Extrait
#   Facettes : Ambrée;Epicée
#   Date de création : 2025
#   Parfumeurs : Inconnu
#   Titre de description : Lacoste Original Parfum – Carte d’identité
#   Texte de description : Lacoste Original Parfum – Carte d’identitéLe crocodile passe au concentré : énergie sport-chic à 25 %Quarante ans après le lancement du tout premier jus Lacoste, la marque dévoile Lacoste Original Parfum, nouveauté 2025 et version la plus intense jamais proposée. Formulé à 25 % d’essence aromatique, ce concentré réinterprète la fougère boisée emblématique en poussant chaque facette à son paroxysme : gingembre-cardamome plus piquants, lavande-encens plus fumés, tonka-patchouli plus enveloppants. Pensé comme le moment charnière où l’adrénaline du match cède la place à l’élégance du vestiaire privé, il célèbre le mantra maison : « Play Hard, Stay Original ».
#   Notes de tête : Bergamote;Cardamome;Poivre
#   Notes de cœur : Lavande;Lavandin;Sauge sclarée
#   Notes de fond : Fève tonka;Patchouli;Santal
# --------------------------------------------------
# Parfum trouvé :
#   Nom : A*Men Stellar
#   URL : https://www.olfastory.com/parfum/amen-stellar
#   Marque : Thierry Mugler
#   Type : Eau de parfum
#   Année : 2025
#   Genre : Homme
#   Famille olfactive : Boisée
#   URL de l'image : https://www.olfastory.com/sites/www.olfastory.com/files/styles/300x300/public/amen-stellar-mugler.jpg?itok=B5HndNvQ
#   Concentration : Eau de parfum
#   Facettes : Aromatique;Gourmande
#   Date de création : 2025
#   Parfumeurs : Jacques Huclier;Louise Turner
#   Titre de description : A*Men Stellar : la nouvelle détonation gourmande-cosmique signée Mugler
#   Texte de description : A*Men Stellar : la nouvelle détonation gourmande-cosmique signée MuglerLa saga A*Men se propulse dans la galaxieDepuis 1996, A*Men réinvente la gourmandise masculine avec une succession de flankers toujours plus audacieux. Après les déclinaisons Pure Coffee, Pure Malt, Infrared ou Ultimate, Mugler présente en avril 2025 A*Men Stellar, un Eau de Parfum qui troque la signature café-patchouli originelle pour un accord pistache crémeuse percuté d’étincelles de bergamote et de lavandin lumineux. L’idée ? Offrir à l’icône « star-man » une ascension interstellaire, entre plaisir gourmand et facette métallique-boisée évoquant la coque d’un vaisseau spatial.
#   Notes de tête : Bergamote;Lavande
#   Notes de cœur : Pistache
#   Notes de fond : Notes Boisées
# --------------------------------------------------
# Parfum trouvé :
#   Nom : Code Elixir
#   URL : https://www.olfastory.com/parfum/code-elixir
#   Marque : Armani
#   Type : Eau de parfum
#   Année : 2025
#   Genre : Homme
#   Famille olfactive : Orientale
#   URL de l'image : https://www.olfastory.com/sites/www.olfastory.com/files/styles/300x300/public/armani-code-elixir.jpg?itok=5NnpVdO3
#   Concentration : Eau de parfum
#   Facettes : Ambrée;Cuir;Epicée
#   Date de création : 2025
#   Parfumeurs : Inconnu
#   Titre de description : Armani Code Elixir : la nouvelle décharge d’intensité de Giorgio Armani
#   Texte de description : Armani Code Elixir : la nouvelle décharge d’intensité de Giorgio ArmaniLe Code le plus concentré à ce jourDévoilé au printemps 2025, Armani Code Elixir se présente comme la version la plus puissante et la plus sensuelle de la lignée amorcée en 2004. Cette concentration parfum combine un cœur cuir-liquor à des épices fumées, sur une base de tonka grillée, offrant une facette ambrée-cuir inédite dans la collection.
#   Notes de tête : Mandarine
#   Notes de cœur : Cuir
#   Notes de fond : Fève tonka
# --------------------------------------------------
# Parfum trouvé :
#   Nom : Spicebomb Metallic Musk
#   URL : https://www.olfastory.com/parfum/spicebomb-metallic-musk
#   Marque : Viktor & Rolf
#   Type : Eau de parfum
#   Année : 2025
#   Genre : Homme
#   Famille olfactive : Boisée
#   URL de l'image : https://www.olfastory.com/sites/www.olfastory.com/files/styles/300x300/public/spicebomb-metallic-musk-viktor-rolf.jpg?itok=qXBd6Drd
#   Concentration : Eau de parfum
#   Facettes : Cuir;Epicée;Musquée
#   Date de création : 2025
#   Parfumeurs : Jean-Christophe Herault
#   Titre de description : Spicebomb Metallic Musk : la nouvelle décharge d’adrénaline chromée signée Viktor&Rolf
#   Texte de description : Spicebomb Metallic Musk : la nouvelle décharge d’adrénaline chromée signée Viktor&RolfPourquoi « Metallic Musk » ?Lancé au printemps 2025, Spicebomb Metallic Musk représente la troisième évolution « collector » du célèbre flacon-grenade : après Infrared et Night Vision, Viktor&Rolf mise cette fois sur un contraste métal-chair où le poivre noir rencontre un nuage de muscs blancs.Les créateurs décrivent la fragrance comme « la collision d’une giclée d’épices brûlantes contre un miroir de daim argenté » – un clin d’œil à la veste lamée de leur défilé couture AH 2025 presque entièrement réalisée… en papier aluminium.
#   Notes de tête : Agrumes;Aldéhydes
#   Notes de cœur : Cannelle;Lavandin;Poivre
#   Notes de fond : Daim;Musc
# --------------------------------------------------
# Parfum trouvé :
#   Nom : Explorer Extreme
#   URL : https://www.olfastory.com/parfum/explorer-extreme
#   Marque : Montblanc
#   Type : Eau de parfum
#   Année : 2025
#   Genre : Homme
#   Famille olfactive : Boisée
#   URL de l'image : https://www.olfastory.com/sites/www.olfastory.com/files/styles/300x300/public/explorer-extreme-montblanc.jpg?itok=UkOGXb7j
#   Concentration : Eau de parfum
#   Facettes : Ambrée;Cuir
#   Date de création : 2025
#   Parfumeurs : Jordi Fernandez;Antoine Maisondieu
#   Titre de description : Explorer Extreme : la nouvelle aventure olfactive signée Montblanc
#   Texte de description : Explorer Extreme : la nouvelle aventure olfactive signée MontblancDe Explorer (2019) à Explorer Extreme (2025)Six ans après le succès planétaire d’Explorer, Montblanc lève le voile sur Explorer Extreme, présenté en avant-première fin mai 2025 et mis en vente mondiale le 2 juin suivant.Conçu comme le chapitre le plus intense de la saga, ce flanker « Parfum » vise les aventuriers urbains en quête de sensations extrêmes : plus sombre, plus épicé, plus racé que l’original.
#   Notes de tête : Bergamote
#   Notes de cœur : Patchouli;Vétiver
#   Notes de fond : Ambre;Cuir;Notes Boisées
# --------------------------------------------------
# Parfum trouvé :
#   Nom : habit rouge privée
#   URL : https://www.olfastory.com/parfum/habit-rouge-privee
#   Marque : Guerlain
#   Type : Eau de parfum
#   Année : 2023
#   Genre : Homme
#   Famille olfactive : Hespéridée
#   URL de l'image : https://www.olfastory.com/sites/www.olfastory.com/files/styles/300x300/public/habit-rouge-pivee.jpg?itok=r96Bpx22
#   Concentration : Eau de parfum
#   Facettes : Cuir
#   Date de création : 2023
#   Parfumeurs : Delphine Jelk
#   Titre de description : Inconnu
#   Texte de description : La dynastie des Guerlain a toujours été profondément attachée aux chevaux. Pour preuve, Jean-Paul Guerlain était lui-même un dresseur hors pair et un cavalier émérite. C'est donc en s'inspirant de cette passion qu'il confectionna l'un de ses premiers parfums : Habit Rouge. Depuis sa sortie en 1965, cette fragrance masculine est considérée comme une légende olfactive. En 2023, Habit Rouge ne cesse d'ailleurs de faire parler de lui. Il revient dans un nouveau dérivé encore plus intense : Habit Rouge - Rouge Privé.
#   Notes de tête : Bergamote;Gingembre
#   Notes de cœur : Iris;Fleur d'Oranger
#   Notes de fond : Cuir;Vanille;Patchouli
# --------------------------------------------------
#
# Scraping https://www.olfastory.com/parfum/homme (Page 1)
#
# === Parfums de la catégorie : https://www.olfastory.com/parfum/homme?page=0 (Page 1) ===
#
# Parfum trouvé :
#   Nom : Acqua di Giò Profondo
#   URL : https://www.olfastory.com/parfum/acqua-di-gio-profondo-0
#   Marque : Armani
#   Type : Eau de toilette
#   Année : 2025
#   Genre : Homme
#   Famille olfactive : Aromatique
#   URL de l'image : https://www.olfastory.com/sites/www.olfastory.com/files/styles/300x300/public/acqua-di-gio-profondo-eau-de-toilette.jpg?itok=N2WigyFu
#   Concentration : Eau de toilette
#   Facettes : Marine
#   Date de création : 2025
#   Parfumeurs : Alberto Morillas
#   Titre de description : Présentation du parfum
#   Texte de description : Présentation du parfumImmersion dans le bleu profondSortie printemps 2025, cette Eau de Toilette revisite la signature marine d’Armani : plus aérienne que l’édition Parfum, elle retranscrit l’instant où la lumière filtre sous la surface. Conçue par Alberto Morillas, la composition unit fraîcheur, minéralité et élégance italienne.
#   Notes de tête : Cardamome;Citron;Mandarine;Pamplemousse
#   Notes de cœur : Cyprès;Lavandin;Note marine;Sauge sclarée
#   Notes de fond : Musc;Patchouli
# --------------------------------------------------
# Parfum trouvé :
#   Nom : L.12.12 Silver Grey
#   URL : https://www.olfastory.com/parfum/l1212-silver-grey
#   Marque : Lacoste
#   Type : Eau de parfum
#   Année : 2025
#   Genre : Homme
#   Famille olfactive : Fougère
#   URL de l'image : https://www.olfastory.com/sites/www.olfastory.com/files/styles/300x300/public/l1212-silver-grey-lacoste.jpg?itok=cZ-2tL94
#   Concentration : Eau de parfum
#   Facettes : Boisée
#   Date de création : 2025
#   Parfumeurs : Bruno Jovanovic
#   Titre de description : Présentation du parfum Lacoste L.12.12 Silver Grey
#   Texte de description : Présentation du parfum Lacoste L.12.12 Silver GreyADN fougère-boisée sport-chicLancé au printemps 2025, Silver Grey incarne la veine athleisure de Lacoste : un souffle fougère-boisé qui marie mandarine zestée, encens minéral, lavande aromatique et ambrox boisé pour un contraste chaud-froid racé.Inspiration métallique & héritage poloLe flacon gris miroir rappelle la première raquette acier de René Lacoste et réinterprète le fameux « petit piqué » du polo L.12.12, symbole d’élégance décontractée.
#   Notes de tête : Encens;Mandarine
#   Notes de cœur : Géranium;Lavande
#   Notes de fond : Ambroxan;Vétiver
# --------------------------------------------------
# Parfum trouvé :
#   Nom : Original
#   URL : https://www.olfastory.com/parfum/original
#   Marque : Lacoste
#   Type : Extrait
#   Année : 2025
#   Genre : Homme
#   Famille olfactive : Fougère
#   URL de l'image : https://www.olfastory.com/sites/www.olfastory.com/files/styles/300x300/public/lacoste-orignal-pafum.jpg?itok=rijwQRYa
#   Concentration : Extrait
#   Facettes : Ambrée;Epicée
#   Date de création : 2025
#   Parfumeurs : Inconnu
#   Titre de description : Lacoste Original Parfum – Carte d’identité
#   Texte de description : Lacoste Original Parfum – Carte d’identitéLe crocodile passe au concentré : énergie sport-chic à 25 %Quarante ans après le lancement du tout premier jus Lacoste, la marque dévoile Lacoste Original Parfum, nouveauté 2025 et version la plus intense jamais proposée. Formulé à 25 % d’essence aromatique, ce concentré réinterprète la fougère boisée emblématique en poussant chaque facette à son paroxysme : gingembre-cardamome plus piquants, lavande-encens plus fumés, tonka-patchouli plus enveloppants. Pensé comme le moment charnière où l’adrénaline du match cède la place à l’élégance du vestiaire privé, il célèbre le mantra maison : « Play Hard, Stay Original ».
#   Notes de tête : Bergamote;Cardamome;Poivre
#   Notes de cœur : Lavande;Lavandin;Sauge sclarée
#   Notes de fond : Fève tonka;Patchouli;Santal
# --------------------------------------------------
# Parfum trouvé :
#   Nom : A*Men Stellar
#   URL : https://www.olfastory.com/parfum/amen-stellar
#   Marque : Thierry Mugler
#   Type : Eau de parfum
#   Année : 2025
#   Genre : Homme
#   Famille olfactive : Boisée
#   URL de l'image : https://www.olfastory.com/sites/www.olfastory.com/files/styles/300x300/public/amen-stellar-mugler.jpg?itok=B5HndNvQ
#   Concentration : Eau de parfum
#   Facettes : Aromatique;Gourmande
#   Date de création : 2025
#   Parfumeurs : Jacques Huclier;Louise Turner
#   Titre de description : A*Men Stellar : la nouvelle détonation gourmande-cosmique signée Mugler
#   Texte de description : A*Men Stellar : la nouvelle détonation gourmande-cosmique signée MuglerLa saga A*Men se propulse dans la galaxieDepuis 1996, A*Men réinvente la gourmandise masculine avec une succession de flankers toujours plus audacieux. Après les déclinaisons Pure Coffee, Pure Malt, Infrared ou Ultimate, Mugler présente en avril 2025 A*Men Stellar, un Eau de Parfum qui troque la signature café-patchouli originelle pour un accord pistache crémeuse percuté d’étincelles de bergamote et de lavandin lumineux. L’idée ? Offrir à l’icône « star-man » une ascension interstellaire, entre plaisir gourmand et facette métallique-boisée évoquant la coque d’un vaisseau spatial.
#   Notes de tête : Bergamote;Lavande
#   Notes de cœur : Pistache
#   Notes de fond : Notes Boisées
# --------------------------------------------------
# Parfum trouvé :
#   Nom : Code Elixir
#   URL : https://www.olfastory.com/parfum/code-elixir
#   Marque : Armani
#   Type : Eau de parfum
#   Année : 2025
#   Genre : Homme
#   Famille olfactive : Orientale
#   URL de l'image : https://www.olfastory.com/sites/www.olfastory.com/files/styles/300x300/public/armani-code-elixir.jpg?itok=5NnpVdO3
#   Concentration : Eau de parfum
#   Facettes : Ambrée;Cuir;Epicée
#   Date de création : 2025
#   Parfumeurs : Inconnu
#   Titre de description : Armani Code Elixir : la nouvelle décharge d’intensité de Giorgio Armani
#   Texte de description : Armani Code Elixir : la nouvelle décharge d’intensité de Giorgio ArmaniLe Code le plus concentré à ce jourDévoilé au printemps 2025, Armani Code Elixir se présente comme la version la plus puissante et la plus sensuelle de la lignée amorcée en 2004. Cette concentration parfum combine un cœur cuir-liquor à des épices fumées, sur une base de tonka grillée, offrant une facette ambrée-cuir inédite dans la collection.
#   Notes de tête : Mandarine
#   Notes de cœur : Cuir
#   Notes de fond : Fève tonka
# --------------------------------------------------
# Parfum trouvé :
#   Nom : Spicebomb Metallic Musk
#   URL : https://www.olfastory.com/parfum/spicebomb-metallic-musk
#   Marque : Viktor & Rolf
#   Type : Eau de parfum
#   Année : 2025
#   Genre : Homme
#   Famille olfactive : Boisée
#   URL de l'image : https://www.olfastory.com/sites/www.olfastory.com/files/styles/300x300/public/spicebomb-metallic-musk-viktor-rolf.jpg?itok=qXBd6Drd
#   Concentration : Eau de parfum
#   Facettes : Cuir;Epicée;Musquée
#   Date de création : 2025
#   Parfumeurs : Jean-Christophe Herault
#   Titre de description : Spicebomb Metallic Musk : la nouvelle décharge d’adrénaline chromée signée Viktor&Rolf
#   Texte de description : Spicebomb Metallic Musk : la nouvelle décharge d’adrénaline chromée signée Viktor&RolfPourquoi « Metallic Musk » ?Lancé au printemps 2025, Spicebomb Metallic Musk représente la troisième évolution « collector » du célèbre flacon-grenade : après Infrared et Night Vision, Viktor&Rolf mise cette fois sur un contraste métal-chair où le poivre noir rencontre un nuage de muscs blancs.Les créateurs décrivent la fragrance comme « la collision d’une giclée d’épices brûlantes contre un miroir de daim argenté » – un clin d’œil à la veste lamée de leur défilé couture AH 2025 presque entièrement réalisée… en papier aluminium.
#   Notes de tête : Agrumes;Aldéhydes
#   Notes de cœur : Cannelle;Lavandin;Poivre
#   Notes de fond : Daim;Musc
# --------------------------------------------------
# Parfum trouvé :
#   Nom : Explorer Extreme
#   URL : https://www.olfastory.com/parfum/explorer-extreme
#   Marque : Montblanc
#   Type : Eau de parfum
#   Année : 2025
#   Genre : Homme
#   Famille olfactive : Boisée
#   URL de l'image : https://www.olfastory.com/sites/www.olfastory.com/files/styles/300x300/public/explorer-extreme-montblanc.jpg?itok=UkOGXb7j
#   Concentration : Eau de parfum
#   Facettes : Ambrée;Cuir
#   Date de création : 2025
#   Parfumeurs : Jordi Fernandez;Antoine Maisondieu
#   Titre de description : Explorer Extreme : la nouvelle aventure olfactive signée Montblanc
#   Texte de description : Explorer Extreme : la nouvelle aventure olfactive signée MontblancDe Explorer (2019) à Explorer Extreme (2025)Six ans après le succès planétaire d’Explorer, Montblanc lève le voile sur Explorer Extreme, présenté en avant-première fin mai 2025 et mis en vente mondiale le 2 juin suivant.Conçu comme le chapitre le plus intense de la saga, ce flanker « Parfum » vise les aventuriers urbains en quête de sensations extrêmes : plus sombre, plus épicé, plus racé que l’original.
#   Notes de tête : Bergamote
#   Notes de cœur : Patchouli;Vétiver
#   Notes de fond : Ambre;Cuir;Notes Boisées
# --------------------------------------------------
# Parfum trouvé :
#   Nom : habit rouge privée
#   URL : https://www.olfastory.com/parfum/habit-rouge-privee
#   Marque : Guerlain
#   Type : Eau de parfum
#   Année : 2023
#   Genre : Homme
#   Famille olfactive : Hespéridée
#   URL de l'image : https://www.olfastory.com/sites/www.olfastory.com/files/styles/300x300/public/habit-rouge-pivee.jpg?itok=r96Bpx22
#   Concentration : Eau de parfum
#   Facettes : Cuir
#   Date de création : 2023
#   Parfumeurs : Delphine Jelk
#   Titre de description : Inconnu
#   Texte de description : La dynastie des Guerlain a toujours été profondément attachée aux chevaux. Pour preuve, Jean-Paul Guerlain était lui-même un dresseur hors pair et un cavalier émérite. C'est donc en s'inspirant de cette passion qu'il confectionna l'un de ses premiers parfums : Habit Rouge. Depuis sa sortie en 1965, cette fragrance masculine est considérée comme une légende olfactive. En 2023, Habit Rouge ne cesse d'ailleurs de faire parler de lui. Il revient dans un nouveau dérivé encore plus intense : Habit Rouge - Rouge Privé.
#   Notes de tête : Bergamote;Gingembre
#   Notes de cœur : Iris;Fleur d'Oranger
#   Notes de fond : Cuir;Vanille;Patchouli
# --------------------------------------------------
#
# Scraping https://www.olfastory.com/parfum/homme (Page 2)
#
# === Parfums de la catégorie : https://www.olfastory.com/parfum/homme?page=1 (Page 2) ===
#
# Parfum trouvé :
#   Nom : boss bottled pacific
#   URL : https://www.olfastory.com/parfum/boss-bottled-pacific
#   Marque : Hugo Boss
#   Type : Eau de parfum
#   Année : 2023
#   Genre : Homme
#   Famille olfactive : Boisée
#   URL de l'image : https://www.olfastory.com/sites/www.olfastory.com/files/styles/300x300/public/boss-bottled-pacific.jpg?itok=ZnwgjPLO
#   Concentration : Eau de parfum
#   Facettes : Boisée
#   Date de création : 2023
#   Parfumeurs : Sophie Labbé
#   Titre de description : Inconnu
#   Texte de description : Faut-il encore le présenter ? Boss Bottled est un parfum de la marque Hugo Boss qui a été élaboré en 1998. Savant mélange de classicisme et de modernité, il est aujourd'hui l'un des jus les plus célèbres de la parfumerie masculine. Fort de son succès, Boss Bottled est également réinterprété année après année, pour dévoiler d'autres dérivés de sa senteur. En 2023, il donne ainsi naissance à un nouveau parfum très rafraîchissant, comme sorti tout droit de l'océan. FOCUS sur Boss Bottled Pacific d’Hugo Boss.
#   Notes de tête : Sel;Noix de coco;Cyprès
#   Notes de cœur : Patchouli;Bois de Cachemire
#   Notes de fond : Santal;Citron
# --------------------------------------------------
# Parfum trouvé :
#   Nom : Le Male Elixir
#   URL : https://www.olfastory.com/parfum/le-male-elixir
#   Marque : Jean-Paul Gaultier
#   Type : Eau de parfum
#   Année : 2023
#   Genre : Homme
#   Famille olfactive : Aromatique
#   URL de l'image : https://www.olfastory.com/sites/www.olfastory.com/files/styles/300x300/public/le-mal-elixir-gaultier.jpg?itok=UASMw8pI
#   Concentration : Eau de parfum
#   Facettes : Ambrée
#   Date de création : 2023
#   Parfumeurs : Inconnu
#   Titre de description : Inconnu
#   Texte de description : Bien plus qu'une simple fragrance masculine, Le Male de Jean-Paul Gaultier est une véritable icône dans l'univers de la parfumerie. Tout d'abord, il s'agissait du tout premier parfum du couturier. Le Male fut également la première création du nez Francis Kurkdjian. Qui plus est, malgré ses presque 30 ans d'existence, Le Male Elixir de Jean-Paul Gaultier demeure le best-seller incontesté de la marque. En 2023, il est donc remis à l'honneur. S'inspirant toujours de l'univers maritime, il devient plus sophistiqué et infiniment chic, dans sa nouvelle édition Le Male Elixir de Jean-Paul Gaultier.
#   Notes de tête : Lavande
#   Notes de cœur : Benjoin
#   Notes de fond : Fève tonka
# --------------------------------------------------
# Parfum trouvé :
#   Nom : Lacoste L.12.12 Blanc Eau Intense
#   URL : https://www.olfastory.com/parfum/lacoste-l1212-blanc-eau-intense
#   Marque : Lacoste
#   Type : Eau de toilette
#   Année : 2023
#   Genre : Homme
#   Famille olfactive : Hespéridée
#   URL de l'image : https://www.olfastory.com/sites/www.olfastory.com/files/styles/300x300/public/lacoste-l-12-12-blanc-intense.jpg?itok=1Hju4mYe
#   Concentration : Eau de toilette
#   Facettes : Epicée
#   Date de création : 2023
#   Parfumeurs : Jean-Christophe Herault;Delphine Lebeau
#   Titre de description : Inconnu
#   Texte de description : René Lacoste était un immense joueur de tennis. Redouté par ses adversaires, il acheva sa carrière après un brillant parcours, dans les années 20. Puis, il décida de lancer sa propre marque de vêtements, toujours très inspirée de l'univers sportif. C'est ainsi que le polo Lacoste fit son apparition, en 1927. Près d'un siècle après sa sortie, il demeure l'un des vêtements les plus convoités de la planète. Mieux encore : il est la source d'inspiration d'une ligne de parfums initiée en 2011. En 2023, celle-ci s'enrichit d'une nouvelle création nommée Lacoste L.12.12 Blanc Eau Intense.
#   Notes de tête : Mandarine;Curcuma
#   Notes de cœur : Lavande;Cardamome;Sauge sclarée
#   Notes de fond : Cuir;Santal;Vétiver
# --------------------------------------------------
# Parfum trouvé :
#   Nom : Rochas Man Intense
#   URL : https://www.olfastory.com/parfum/rochas-man-intense
#   Marque : Rochas
#   Type : Eau de parfum
#   Année : 2023
#   Genre : Homme
#   Famille olfactive : Boisée
#   URL de l'image : https://www.olfastory.com/sites/www.olfastory.com/files/styles/300x300/public/rochas-man-intense.jpg?itok=PmFV8fRh
#   Concentration : Eau de parfum
#   Facettes : Ambrée
#   Date de création : 2023
#   Parfumeurs : Inconnu
#   Titre de description : Inconnu
#   Texte de description : En 1993, la maison Rochas décida d'offrir un premier parfum à la gent masculine. Il s'agissait de la version homme de l'indémodable Eau de Rochas. Puis, Rochas Man fut conçu quelques années plus tard, en 1999, comme pour s'adresser aux hommes du nouveau millénaire. Avec le design audacieux de son flacon et sa senteur orientale et boisée, cette essence ne passa pas inaperçue. En 2023, Rochas décide de la remettre à l'honneur dans une édition encore plus suave et addictive. C'est ainsi qu'apparaît Rochas Man Intense.
#   Notes de tête : Lavande;Agrumes
#   Notes de cœur : Cèdre;Cappuccino
#   Notes de fond : Vanille
# --------------------------------------------------
# Parfum trouvé :
#   Nom : Grey Vetiver Parfum
#   URL : https://www.olfastory.com/parfum/grey-vetiver-parfum
#   Marque : Tom Ford
#   Type : Eau de parfum
#   Année : 2023
#   Genre : Homme
#   Famille olfactive : Boisée
#   URL de l'image : https://www.olfastory.com/sites/www.olfastory.com/files/styles/300x300/public/grey-vetiver-parfum-tom-ford.jpg?itok=oYoQYgMv
#   Concentration : Eau de parfum
#   Facettes : Epicée
#   Date de création : 2023
#   Parfumeurs : Inconnu
#   Titre de description : Inconnu
#   Texte de description : Thomas Carlyle Ford est un créateur d'origine texane, qui est né en 1961 et qui a étudié dans différents domaines tels que l'art et l'architecture. Finalement, c'est avec ses créations couture qu'il se fit un nom dans l'univers du luxe. Depuis 2005, Tom Ford possède sa propre marque. Symbole d'élégance à travers le monde, il élabore également des parfums en accord avec son sens inouï du raffinement. C'est ainsi qu'a d'abord été conçu Grey Vetiver en 2009, avant de devenir une Eau de Toilette plus légère en 2014 ou un jus plus puissant en 2023 : Grey Vetiver Parfum.
#   Notes de tête : Vétiver
#   Notes de cœur : Fleur d'Oranger
#   Notes de fond : Safran
# --------------------------------------------------
# Parfum trouvé :
#   Nom : Azzaro Wanted Eau de Parfum
#   URL : https://www.olfastory.com/parfum/azzaro-wanted-eau-de-parfum
#   Marque : Azzaro
#   Type : Eau de parfum
#   Année : 2023
#   Genre : Homme
#   Famille olfactive : Boisée
#   URL de l'image : https://www.olfastory.com/sites/www.olfastory.com/files/styles/300x300/public/azzaro-eau-parfum.jpg?itok=LPo5MmL3
#   Concentration : Eau de parfum
#   Facettes : Aromatique
#   Date de création : 2023
#   Parfumeurs : Inconnu
#   Titre de description : Inconnu
#   Texte de description : Loris Azzaro était un personnage ambitieux et un véritable amoureux des femmes. Ainsi, il leur consacra sa carrière tout entière et parvint à conquérir le cœur des stars les plus éblouissantes de la planète, grâce à ses robes époustouflantes. Tout au long de sa vie, Loris Azzaro n'a jamais hésité à faire le grand saut et à saisir sa chance. C'est donc à cette image qu'a aussi été conçue la saga parfumée masculine Azzaro Wanted, en 2019. En 2023, un nouveau jus nommé Azzaro Wanted Eau de Parfum vient rejoindre cette ligne de fragrances pour hommes.
#   Notes de tête : Baies de genévrier
#   Notes de cœur : Sauge sclarée
#   Notes de fond : Vétiver
# --------------------------------------------------
# Parfum trouvé :
#   Nom : L’Eau d’Issey pour Homme Vetiver
#   URL : https://www.olfastory.com/parfum/leau-dissey-pour-homme-vetiver
#   Marque : Issey Miyaké
#   Type : Eau de parfum
#   Année : 2023
#   Genre : Homme
#   Famille olfactive : Aromatique
#   URL de l'image : https://www.olfastory.com/sites/www.olfastory.com/files/styles/300x300/public/l-eau-d-issey-homme-vetiver.jpg?itok=tffkEebE
#   Concentration : Eau de parfum
#   Facettes : Boisée
#   Date de création : 2023
#   Parfumeurs : Inconnu
#   Titre de description : Inconnu
#   Texte de description : En 1992, la parfumerie se caractérisait par des fragrances souvent très opulentes, capiteuses et orientales. Quelle ne fut pas la surprise de voir apparaître un parfum pour femme limpide et très épuré nommé L’Eau d’Issey… Pourtant, cette essence pour femme remporta aussitôt un immense succès. À peine deux ans plus tard, celle-ci se déclina en une édition masculine. Près de 30 ans après la création de L’Eau d’Issey pour Homme, Issey Miyake réinterprète cette essence star pour en faire L’Eau d’Issey pour Homme Vetiver.
#   Notes de tête : Vétiver
#   Notes de cœur : Gingembre
#   Notes de fond : Sauge sclarée
# --------------------------------------------------
# Parfum trouvé :
#   Nom : Hugo Jeans
#   URL : https://www.olfastory.com/parfum/hugo-jeans
#   Marque : Hugo Boss
#   Type : Eau de parfum
#   Année : 2023
#   Genre : Homme
#   Famille olfactive : Aromatique
#   URL de l'image : https://www.olfastory.com/sites/www.olfastory.com/files/styles/300x300/public/hugo-boss-jeans.jpg?itok=A9xGHEOY
#   Concentration : Eau de parfum
#   Facettes : Boisée
#   Date de création : 2023
#   Parfumeurs : Inconnu
#   Titre de description : Inconnu
#   Texte de description : La marque Hugo Boss est très réputée pour ses costumes. En effet, elle est actuellement l'une des enseignes les plus plébiscitées pour habiller les hommes d'affaires ambitieux et carriéristes. Ces derniers sont parfaitement coupés et sont élaborés dans des textiles d'exception. Néanmoins, Hugo Boss se plaît aussi à offrir aux hommes un style plus décontracté. Voilà pourquoi l'enseigne confectionne aussi des jeans de haute qualité. Or, ce sont précisément ces derniers qui ont inspiré le dernier parfum masculin Hugo Boss : Hugo Jeans.
#   Notes de tête : Pamplemousse;Citron
#   Notes de cœur : Baies de genévrier;Menthe
#   Notes de fond : Cèdre;Vétiver
# --------------------------------------------------
#
# Scraping https://www.olfastory.com/parfum/homme (Page 3)
#
# === Parfums de la catégorie : https://www.olfastory.com/parfum/homme?page=2 (Page 3) ===
#
# Parfum trouvé :
#   Nom : Born in Rome Intense Uomo
#   URL : https://www.olfastory.com/parfum/born-rome-intense-uomo
#   Marque : Valentino
#   Type : Eau de parfum
#   Année : 2023
#   Genre : Homme
#   Famille olfactive : Fougère
#   URL de l'image : https://www.olfastory.com/sites/www.olfastory.com/files/styles/300x300/public/born-in-roma-intense-uomo_0.jpg?itok=WBU_aZsK
#   Concentration : Eau de parfum
#   Facettes : Fougère
#   Date de création : 2023
#   Parfumeurs : Guillaume Flavigny;Antoine Maisondieu
#   Titre de description : Inconnu
#   Texte de description : Valentino est une grande maison de couture qui a été fondée à Rome en 1960. Très imprégnée de la tradition italienne, elle est aujourd'hui dirigée d'une main de maître par le talentueux Pierpaolo Piccioli. Symbole de renouveau et de modernité, il y célèbre désormais l'image d'une ville en pleine mutation, alliant innovation et tradition. Dans ce virage créatif, il élabore aussi des parfums à la frontière des époques, comme en témoigne la fragrance masculine Born in Roma Intense Uomo.
#   Notes de tête : Vanille
#   Notes de cœur : Lavande
#   Notes de fond : Vétiver
# --------------------------------------------------
# Parfum trouvé :
#   Nom : Boss The Scent Magnetic
#   URL : https://www.olfastory.com/parfum/boss-scent-magnetic
#   Marque : Hugo Boss
#   Type : Eau de parfum
#   Année : 2023
#   Genre : Homme
#   Famille olfactive : Aromatique
#   URL de l'image : https://www.olfastory.com/sites/www.olfastory.com/files/styles/300x300/public/hugo-boss-the-scent-magnetic.jpg?itok=1OyKCwx_
#   Concentration : Eau de parfum
#   Facettes : Poudrée
#   Date de création : 2023
#   Parfumeurs : Delphine Lebeau
#   Titre de description : Inconnu
#   Texte de description : Réputé dans le monde entier pour ses costumes parfaitement coupés, Hugo Boss décida finalement de les accompagner de parfums, dès 1985. Depuis cette date, l'enseigne est un symbole de modernité et de raffinement, accompagnant les hommes et les femmes sur la voie du succès. La collection Boss The Scent, initiée en 2015, s'inscrit donc pleinement dans cette lignée. En 2023, celle-ci s'enrichit d'un nouveau jus, plus intime et invitant rapprochement : Boss The Scent Magnetic.
#   Notes de tête : Maninka
#   Notes de cœur : son de blé
#   Notes de fond : Vanille
# --------------------------------------------------
# Parfum trouvé :
#   Nom : Armani Code Eau de Toilette
#   URL : https://www.olfastory.com/parfum/armani-code-eau-de-toilette
#   Marque : Armani
#   Type : Eau de toilette
#   Année : 2023
#   Genre : Homme
#   Famille olfactive : Boisée
#   URL de l'image : https://www.olfastory.com/sites/www.olfastory.com/files/styles/300x300/public/armani-code-eau-toilette.jpg?itok=twZZovcX
#   Concentration : Eau de toilette
#   Facettes : Aromatique
#   Date de création : 2023
#   Parfumeurs : Inconnu
#   Titre de description : Inconnu
#   Texte de description : Créée en 2004, la collection Armani Code incarne la confiance en soi au masculin et le charisme inné des hommes. Faisant parfaitement écho au dressing Armani, elle est un assortiment de plusieurs essences sophistiquées, dépourvues de superflu et mettant en exergue des ingrédients rigoureusement sélectionnés. En 2023, celle-ci s'enrichit d'un nouveau venu. Armani Code Eau de Toilette marque un réel tournant dans cette histoire, en s'offrant un flacon novateur et une composition très différente.
#   Notes de tête : Mandarine
#   Notes de cœur : Lavande
#   Notes de fond : Fève tonka;Cèdre
# --------------------------------------------------
# Parfum trouvé :
#   Nom : This is Him ! Undressed
#   URL : https://www.olfastory.com/parfum/him-undressed
#   Marque : Zadig & Voltaire
#   Type : Eau de parfum
#   Année : 2023
#   Genre : Homme
#   Famille olfactive : Boisée
#   URL de l'image : https://www.olfastory.com/sites/www.olfastory.com/files/styles/300x300/public/this-is-him-undressed.jpg?itok=qCXVGqe2
#   Concentration : Eau de parfum
#   Facettes : Musquée
#   Date de création : 2023
#   Parfumeurs : Nathalie Lorson
#   Titre de description : Inconnu
#   Texte de description : Zadig & Voltaire est une marque de luxe relativement récente. Qui plus est, celle-ci l'est encore plus lorsqu'il s'agit de parfumerie. Toutefois, force est de constater que son démarrage fut brillamment réussi, comme en témoigne son duo de parfums composé de This is Him et This is Her. Sortis en 2007, les deux acolytes semblent toujours inséparables. En 2023, ils nous livrent d'ailleurs une nouvelle facette de leurs personnalités. Du côté des hommes, le nouveau venu se nomme This is Him ! Undressed de Zadig & Voltaire.
#   Notes de tête : Poivre Rose;Fleur d'Oranger;Pamplemousse
#   Notes de cœur : Musc;Sel;Ambroxan
#   Notes de fond : Cèdre;Santal;Mousse d'arbre
# --------------------------------------------------
# Parfum trouvé :
#   Nom : Azzaro Chrome Parfum
#   URL : https://www.olfastory.com/parfum/azzaro-chrome-parfum
#   Marque : Azzaro
#   Type : Eau de parfum
#   Année : 2023
#   Genre : Homme
#   Famille olfactive : Hespéridée
#   URL de l'image : https://www.olfastory.com/sites/www.olfastory.com/files/styles/300x300/public/azzaro-chrome-parfum.jpg?itok=gsGWP49U
#   Concentration : Eau de parfum
#   Facettes : Aromatique
#   Date de création : 2023
#   Parfumeurs : Inconnu
#   Titre de description : Inconnu
#   Texte de description : Chrome d’Azzaro est un parfum intemporel, qui nous plonge dans l'intimité de Loris Azzaro, fondateur de la marque éponyme, depuis sa sortie en 1996. En effet, il semble posséder en lui tout l'amour du fondateur pour son petit-fils et pour sa région d'origine : la Méditerranée. Une nouvelle fois, en 2003, Azzaro décide de nous livrer une fragrance pour homme synonyme de connivence et de complicité. Cette fois, il s'agit d’Azzaro Chrome Parfum.
#   Notes de tête : Bergamote
#   Notes de cœur : Sauge sclarée
#   Notes de fond : Résine
# --------------------------------------------------
# Parfum trouvé :
#   Nom : Invictus Victory Elixir de Paco Rabanne
#   URL : https://www.olfastory.com/parfum/invictus-victory-elixir-de-paco-rabanne
#   Marque : Paco Rabanne
#   Type : Eau de parfum
#   Année : 2023
#   Genre : Homme
#   Famille olfactive : Boisée
#   URL de l'image : https://www.olfastory.com/sites/www.olfastory.com/files/styles/300x300/public/invictus_victory_elixir_paco_rabanne.jpg?itok=RFi6ruYn
#   Concentration : Eau de parfum
#   Facettes : Ambrée
#   Date de création : 2023
#   Parfumeurs : Inconnu
#   Titre de description : Inconnu
#   Texte de description : Paco Rabanne a toujours aimé surprendre. Couturier prodige, il n'a cessé d'accompagner l'émancipation des hommes et des femmes tout au long de sa carrière. Impertinent et audacieux, il est un personnage visionnaire que certains adorent tandis que d'autres détestent. Qu'à cela ne tienne, Paco Rabanne aime faire parler de lui et force est de constater que cela lui réussit. Sa carrière est une immense victoire. Ainsi, en 2023, Paco Rabanne décide une nouvelle fois de mettre à l'honneur les hommes victorieux. Il vous présente le parfum masculin Invictus Victory Elixir.
#   Notes de tête : Oliban
#   Notes de cœur : Vanille;Ambre
#   Notes de fond : Fève tonka
# --------------------------------------------------
# Parfum trouvé :
#   Nom : 1 Million Royal
#   URL : https://www.olfastory.com/parfum/1-million-royal
#   Marque : Paco Rabanne
#   Type : Eau de parfum
#   Année : 2023
#   Genre : Homme
#   Famille olfactive : Boisée
#   URL de l'image : https://www.olfastory.com/sites/www.olfastory.com/files/styles/300x300/public/1-million-royal-paco-rabanne.jpg?itok=eXatzlcm
#   Concentration : Eau de parfum
#   Facettes : Ambrée
#   Date de création : 2023
#   Parfumeurs : Quentin Bisch;Christophe Raynaud
#   Titre de description : Inconnu
#   Texte de description : Paco Rabanne est un créateur de mode atypique, qui n'a jamais hésité à casser les codes. Ainsi, lorsqu'il conçoit des parfums, il ne se contente pas d'élaborer une senteur. Il imagine aussi une histoire et un univers à part entière. Depuis 2008, 1 Million nous plonge dans un monde luxueux. Celui qui porte ce parfum semble pouvoir tout obtenir d'un simple claquement de doigts. Oriental et fruité, ce jus compte actuellement parmi les best-sellers de Paco Rabanne. En 2023, l'enseigne décide donc d'en élaborer une nouvelle version. Bienvenue dans le royaume de1 Million Royal de Paco Rabanne !
#   Notes de tête : Tangerine;Bergamote;Cardamome
#   Notes de cœur : Lavande;Feuille de violette;Sauge sclarée
#   Notes de fond : Benjoin;Cèdre;Patchouli
# --------------------------------------------------
# Parfum trouvé :
#   Nom : Y Eau de Parfum Intense
#   URL : https://www.olfastory.com/parfum/y-eau-de-parfum-intense
#   Marque : Yves Saint Laurent
#   Type : Eau de parfum
#   Année : 2023
#   Genre : Homme
#   Famille olfactive : Aromatique
#   URL de l'image : https://www.olfastory.com/sites/www.olfastory.com/files/styles/300x300/public/y-eau-parfum-intense.jpg?itok=eoN0VI-I
#   Concentration : Eau de parfum
#   Facettes : Fougère
#   Date de création : 2023
#   Parfumeurs : Dominique Ropion
#   Titre de description : Inconnu
#   Texte de description : Yves Saint-Laurent est un personnage atypique qui n'a jamais cessé de surprendre tout au long de son histoire. Derrière son apparente timidité, il cachait un esprit novateur. Travailleur acharné, il a littéralement révolutionné la mode jusqu'à atteindre le plein accomplissement. Or, c'est précisément toutes les valeurs que l'on retrouve dans la collection Y d'Yves Saint-Laurent. Initiée en 2017, celle-ci s'enrichit d'une nouvelle édition plus audacieuse, en 2023 : Y Eau de Parfum Intense.
#   Notes de tête : Gingembre;Bergamote;Baies de genévrier
#   Notes de cœur : Sauge sclarée;Géranium;Lavande
#   Notes de fond : Vétiver;Patchouli;Cèdre
# --------------------------------------------------
#
# Scraping https://www.olfastory.com/parfum/homme (Page 4)
#
# === Parfums de la catégorie : https://www.olfastory.com/parfum/homme?page=3 (Page 4) ===
#
# Parfum trouvé :
#   Nom : Gentleman Society de Givenchy
#   URL : https://www.olfastory.com/parfum/gentleman-society-de-givenchy
#   Marque : Givenchy
#   Type : Eau de parfum
#   Année : 2023
#   Genre : Homme
#   Famille olfactive : Aromatique
#   URL de l'image : https://www.olfastory.com/sites/www.olfastory.com/files/styles/300x300/public/gentleman-socity-givenchy.jpg?itok=c4ZfXK40
#   Concentration : Eau de parfum
#   Facettes : Boisée
#   Date de création : 2023
#   Parfumeurs : Inconnu
#   Titre de description : Inconnu
#   Texte de description : En 1975, Hubert de Givenchy avait un pressentiment : il était convaincu que les hommes étaient enfin prêts à découvrir le « vrai parfum », moins timoré et doté d'une réelle personnalité. C'est ainsi qu'il élabora le tout premier Gentleman de Givenchy. En rupture totale avec les fragrances très fraîches de son époque, il affichait un tempérament de feu et le succès fut immédiat ! En 2017, Givenchy décida de moderniser sa fragrance, pour s'adresser aux hommes d'aujourd'hui. En 2023, l'épopée de ce parfum de légende se poursuit. Givenchy vous présente Gentleman Society.
#   Notes de tête : Cardamome;Sauge sclarée
#   Notes de cœur : Narcisse;Vétiver
#   Notes de fond : Vanille;Palo Santo;Cèdre
# --------------------------------------------------
# Parfum trouvé :
#   Nom : Kenzo Homme eau de toilette Marine
#   URL : https://www.olfastory.com/parfum/kenzo-homme-eau-de-toilette-marine
#   Marque : Kenzo
#   Type : Eau de toilette
#   Année : 2023
#   Genre : Homme
#   Famille olfactive : Boisée
#   URL de l'image : https://www.olfastory.com/sites/www.olfastory.com/files/styles/300x300/public/kenzo-homme-eau-toilette-marine-kenzo.jpg?itok=CwNloZtr
#   Concentration : Eau de toilette
#   Facettes : Aromatique
#   Date de création : 2023
#   Parfumeurs : Inconnu
#   Titre de description : Inconnu
#   Texte de description : l'image d'un homme face à l'immensité de la nature Kenzo Homme Eau de Toilette Marine est une création qui nous projette au premier matin du monde, face à une nature encore vierge. Devant la splendeur des éléments, l'homme se tient debout. Il se charge d'énergie au contact du paysage environnant et laisse son regard se perdre à l'horizon. Ici, le décor se veut particulièrement aquatique.
#   Notes de tête : Note marine;Calypsone;Noix de muscade
#   Notes de cœur : Pin;Patchouli
#   Notes de fond : Santal;Cèdre
# --------------------------------------------------
# Parfum trouvé :
#   Nom : Boss Bottled Parfum d’Hugo Boss
#   URL : https://www.olfastory.com/parfum/boss-bottled-parfum-dhugo-boss
#   Marque : Hugo Boss
#   Type : Eau de parfum
#   Année : 2022
#   Genre : Homme
#   Famille olfactive : Boisée
#   URL de l'image : https://www.olfastory.com/sites/www.olfastory.com/files/styles/300x300/public/boss-bottled-parfum.jpg?itok=pO8zFooL
#   Concentration : Eau de parfum
#   Facettes : Boisée
#   Date de création : 2022
#   Parfumeurs : Annick Menardo
#   Titre de description : Inconnu
#   Texte de description : Chez Hugo Boss, l’élégance de l’homme se matérialise par un savant mélange de classicisme et de modernité. C’est ainsi qu’est conçu chacun de ses costumes, dans la plus haute tradition et avec les meilleurs tissus. C’est également ainsi qu’a été élaboré son très célèbre parfum Boss Bottled, en 1998. Aujourd’hui, en 2022, celui-ci est remis à l’honneur dans une nouvelle version, plus sophistiquée et bien plus concentrée. Hugo Boss nous présente Boss Bottled Parfum.
#   Notes de tête : Mandarine;Encens
#   Notes de cœur : Iris;Figuier
#   Notes de fond : Cèdre;Cuir
# --------------------------------------------------
# Parfum trouvé :
#   Nom : Coach Open Road
#   URL : https://www.olfastory.com/parfum/coach-open-road
#   Marque : Coach
#   Type : Eau de cologne
#   Année : 2022
#   Genre : Homme
#   Famille olfactive : Boisée
#   URL de l'image : https://www.olfastory.com/sites/www.olfastory.com/files/styles/300x300/public/coach-open-road.jpg?itok=SNsoXg5r
#   Concentration : Eau de cologne
#   Facettes : Aromatique
#   Date de création : 2022
#   Parfumeurs : Jean-Christophe Herault
#   Titre de description : Inconnu
#   Texte de description : Coach est née au cœur de New York, en 1941. Très célèbre pour ses sacs à main en cuir et ses autres articles de maroquinerie, elle est aujourd'hui dirigée d'une main de maître par le talentueux Stuart Verves. Qui plus est, depuis quelques années, Coach propose également des parfums. En 2022, sa fragrance nous invite à vivre un voyage hors du commun, par-delà les frontières, en direction de la côte ouest-américaine. Le nom de son nouveau périple olfactif ? Coach Open Road.
#   Notes de tête : Citron;Pomme
#   Notes de cœur : Poivre;Sauge sclarée;Lavande
#   Notes de fond : Vétiver;Cèdre;Patchouli
# --------------------------------------------------
# Parfum trouvé :
#   Nom : Ralph's Club Parfum
#   URL : https://www.olfastory.com/parfum/ralphs-club-parfum
#   Marque : Ralph Lauren
#   Type : Eau de parfum
#   Année : 2022
#   Genre : Homme
#   Famille olfactive : Aromatique
#   URL de l'image : https://www.olfastory.com/sites/www.olfastory.com/files/styles/300x300/public/ralph-club-ralph-lauren.jpg?itok=mPvB2Fzj
#   Concentration : Eau de parfum
#   Facettes : Boisée
#   Date de création : 2022
#   Parfumeurs : Dominique Ropion
#   Titre de description : Inconnu
#   Texte de description : S’étant d’abord illustrée dans l’univers de la mode et de la décoration, la maison Ralph Lauren s’est ensuite invitée dans le monde des parfums, en confectionnant notamment des jus masculins, très inspirés de l’univers du polo, sport équestre très cher au cœur du créateur Ralph Lauren. Cependant, l’année 2021 a marqué un tournant dans cette histoire olfactive. Ralph Lauren a donné naissance au tout premier Ralph’s Club, comme pour inviter les hommes dans son univers très sélectif. En 2022, une nouvelle soirée VIP s’annonce. Bienvenue dans le nouveau club privé de Ralph’s Club Parfum !
#   Notes de tête : Lavande;Sauge sclarée
#   Notes de cœur : Cèdre
#   Notes de fond : Vétiver
# --------------------------------------------------
# Parfum trouvé :
#   Nom : Scandal Pour Homme Le Parfum
#   URL : https://www.olfastory.com/parfum/scandal-pour-homme-le-parfum
#   Marque : Jean-Paul Gaultier
#   Type : Eau de parfum
#   Année : 2022
#   Genre : Homme
#   Famille olfactive : Boisée
#   URL de l'image : https://www.olfastory.com/sites/www.olfastory.com/files/styles/300x300/public/scandal-homme-le_parfum-gaultier.jpg?itok=07xTelkG
#   Concentration : Eau de parfum
#   Facettes : Boisée
#   Date de création : 2022
#   Parfumeurs : Inconnu
#   Titre de description : Inconnu
#   Texte de description : Jean-Paul Gaultier est une illustre figure de la mode. Cependant, il n’est pas uniquement connu pour ses créations de vêtements. Il est au moins tout aussi célèbre pour son audace et son sens inné du scandale ! En effet, tout au long de sa carrière, il n’a jamais hésité à surprendre son public. C’est donc tout naturellement qu’il a conçu une eau de toilette féminine nommée Scandal, en 2017. Comptant parmi les best-sellers olfactifs de l’enseigne, ce jus ne cesse, depuis sa sortie, d’être réinventé, année après année. En 2022, son souffle naturellement sulfureux s’intensifie. Jean-Paul Gaultier donne naissance à Scandal Le Parfum.
#   Notes de tête : Géranium
#   Notes de cœur : Fève tonka
#   Notes de fond : Santal
# --------------------------------------------------
# Parfum trouvé :
#   Nom : Code Parfum
#   URL : https://www.olfastory.com/parfum/code-parfum
#   Marque : Armani
#   Type : Extrait
#   Année : 2022
#   Genre : Homme
#   Famille olfactive : Aromatique
#   URL de l'image : https://www.olfastory.com/sites/www.olfastory.com/files/styles/300x300/public/armani-code-parfum_0.jpg?itok=JiQrSA17
#   Concentration : Extrait
#   Facettes : Boisée
#   Date de création : 2022
#   Parfumeurs : Antoine Maisondieu
# ...
#   Notes de tête : Cacao
#   Notes de cœur : Cannelle;Rose
#   Notes de fond : Bois ambrés;Vanille;Santal;Cacao;Cèdre;Réglisse
# --------------------------------------------------
# Parfum trouvé :
#   Nom : Vitriol d'Oeillet
#   URL : https://www.olfastory.com/parfum/vitriol-doeillet
#   Marque : Serge Lutens
#   Type : Eau de parfum
#   Année : 2011
#   Genre : Mixte
#   Famille olfactive : Fleurie
#   URL de l'image : https://www.olfastory.com/sites/www.olfastory.com/files/styles/300x300/public/vitriol-d-oeillet.jpg?itok=y-pKMTYy
#   Concentration : Eau de parfum
#   Facettes : Epicée;Poudrée
#   Date de création : 2011
#   Parfumeurs : Inconnu
#   Titre de description : Vitriol d’Œillet : Une claque de fleurs par Serge Lutens
#   Texte de description : Vitriol d’Œillet : Une claque de fleurs par Serge LutensFéminin-masculin, ou bien encore masculin-féminin, Serge Lutens cultive les genres et s’amuse de ses provocations parfumées et verbales.
#   Notes de tête : Baies roses
#   Notes de cœur : Rose;Oeillet
#   Notes de fond : Patchouli;Santal;Poivre noir;Girofle;Cèdre
# --------------------------------------------------
# Parfum trouvé :
#   Nom : Osmanthus Interdite
#   URL : https://www.olfastory.com/parfum/osmanthus-interdite
#   Marque : Parfum d'Empire
#   Type : Eau de parfum
#   Année : 2007
#   Genre : Mixte
#   Famille olfactive : Fleurie
#   URL de l'image : https://www.olfastory.com/sites/www.olfastory.com/files/styles/300x300/public/osmanthus-interdite.jpg?itok=2Sb8BbIt
#   Concentration : Eau de parfum
#   Facettes : Fruitée
#   Date de création : 2007
#   Parfumeurs : Marc-Antoine Corticchiato
#   Titre de description : Inconnu
#   Texte de description : Chacune des essences de Parfum d'Empire se veut unisexe, convenant tout autant à la gent féminine que masculine. Aussi, Osmanthus Interdite ne déroge pas à la règle.
#   Notes de tête : Aldéhydes;Thé
#   Notes de cœur : Rose;Osmanthus;Jasmin
#   Notes de fond : Muscs blancs
# --------------------------------------------------
# Parfum trouvé :
#   Nom : Equistrius
#   URL : https://www.olfastory.com/parfum/equistrius
#   Marque : Parfum d'Empire
#   Type : Eau de parfum
#   Année : 2007
#   Genre : Mixte
#   Famille olfactive : Boisée
#   URL de l'image : https://www.olfastory.com/sites/www.olfastory.com/files/styles/300x300/public/equistrius.jpg?itok=7F6kveTe
#   Concentration : Eau de parfum
#   Facettes : Musquée;Poudrée
#   Date de création : 2007
#   Parfumeurs : Marc-Antoine Corticchiato
#   Titre de description : Inconnu
#   Texte de description : Equistrius est un parfum à la fois sensuel, racé et élégant. Comme chacun des jus émanant de la marque Parfum d'Empire, il inspire la conquête et semble cette fois mettre à l'honneur l'une des fleurs les plus nobles de tout le rayon de la parfumerie : l'iris de Florence.
#   Notes de tête : Note verte
#   Notes de cœur : Violette
#   Notes de fond : Patchouli;Vanille;Muscs blancs;Santal;Cuir;Iris;Ambrette;Foin
# --------------------------------------------------
#
# Scraping https://www.olfastory.com/parfums/mixte (Page 33)
#
# === Parfums de la catégorie : https://www.olfastory.com/parfums/mixte?page=32 (Page 33) ===
#
# Parfum trouvé :
#   Nom : Musc Tonkin
#   URL : https://www.olfastory.com/parfum/musc-tonkin
#   Marque : Parfum d'Empire
#   Type : Extrait -
#   Année : Inconnu
#   Genre : Mixte
#   Famille olfactive : Chyprée
#   URL de l'image : https://www.olfastory.com/sites/www.olfastory.com/files/styles/300x300/public/musc-tonkin_0.jpg?itok=YIbxfwxH
#   Concentration : Extrait
#   Facettes : Aldéhydée;Cuir
#   Date de création : Inconnu
#   Parfumeurs : Marc-Antoine Corticchiato
#   Titre de description : Inconnu
#   Texte de description : Si Marc-Antoine Corticchiato a décidé de s'installer en tant que parfumeur indépendant en créant sa marque Parfum d’Empire, c'est avant toute chose pour laisser libre cours à son imagination débordante.
#   Notes de tête : Bergamote
#   Notes de cœur : Rose;Aldéhydes;Jasmin;Note marine
#   Notes de fond : Mousse de chêne;Patchouli;Santal;Encens
# --------------------------------------------------
# Parfum trouvé :
#   Nom : La Religieuse
#   URL : https://www.olfastory.com/parfum/la-religieuse
#   Marque : Serge Lutens
#   Type : Eau de parfum
#   Année : 2015
#   Genre : Mixte
#   Famille olfactive : Fleurie
#   URL de l'image : https://www.olfastory.com/sites/www.olfastory.com/files/styles/300x300/public/la-religieuse.jpg?itok=uyHwtLMt
#   Concentration : Eau de parfum
#   Facettes : Inconnu
#   Date de création : 2015
#   Parfumeurs : Christopher Sheldrake
#   Titre de description : La Religieuse : Un parfum de mysticisme guidé par la lumière de Lutens
#   Texte de description : La Religieuse : Un parfum de mysticisme guidé par la lumière de LutensSortie en 2015, la 70e création parfumée de Serge Lutens étonne au moins autant qu’elle dérange tant son apparente pureté se joue de son brin de provocation.
#   Notes de tête : Jasmin
#   Notes de cœur : Encens
#   Notes de fond : Muscs blancs;Civette
# --------------------------------------------------
# Parfum trouvé :
#   Nom : Wazamba
#   URL : https://www.olfastory.com/parfum/wazamba
#   Marque : Parfum d'Empire
#   Type : Eau de parfum
#   Année : 2009
#   Genre : Mixte
#   Famille olfactive : Boisée
#   URL de l'image : https://www.olfastory.com/sites/www.olfastory.com/files/styles/300x300/public/wazamba.jpg?itok=K6muBkjv
#   Concentration : Eau de parfum
#   Facettes : Cuir
#   Date de création : 2009
#   Parfumeurs : Marc-Antoine Corticchiato
#   Titre de description : Inconnu
#   Texte de description : Wazamba est un parfum au nom bien énigmatique à la fois vibrant, sacré et résineux. Celui-ci semble se tourner vers l'esprit divin qui était conféré autrefois au parfum. Il possède des effluves empreints d'une profonde spiritualité et dans lesquels se mêlent les bois précieux et les résines ensorcelantes.
#   Notes de tête : Aldéhydes
#   Notes de cœur : Pomme;Cyprès
#   Notes de fond : Santal;Encens;Myrrhe;Labdanum;Opopanax;Fir balsam
# --------------------------------------------------
# Parfum trouvé :
#   Nom : Oud Al Sahraa
#   URL : https://www.olfastory.com/parfum/oud-al-sahraa
#   Marque : Berdoues
#   Type : Eau de cologne
#   Année : 2015
#   Genre : Mixte
#   Famille olfactive : Orientale
#   URL de l'image : https://www.olfastory.com/sites/www.olfastory.com/files/styles/300x300/public/oud-al-sahraa.jpg?itok=8s5jb1p4
#   Concentration : Eau de cologne
#   Facettes : Epicée
#   Date de création : 2015
#   Parfumeurs : Inconnu
#   Titre de description : Inconnu
#   Texte de description : Oud Al Sahraa est un parfum qui ne cache pas bien longtemps le secret de ses origines. En effet, celui-ci possède des consonances très orientales. Il s'agit d'un jus issu de la Collection des Grands Crus.
#   Notes de tête : Mandarine;Bergamote
#   Notes de cœur : Cannelle;Rose;Poivre noir;Safran;Girofle
#   Notes de fond : Benjoin;Patchouli;Vanille;Myrrhe;Labdanum;Cèdre;Caramel
# --------------------------------------------------
# Parfum trouvé :
#   Nom : Somei Yoshino
#   URL : https://www.olfastory.com/parfum/somei-yoshino
#   Marque : Berdoues
#   Type : Eau de cologne
#   Année : 2015
#   Genre : Mixte
#   Famille olfactive : Fleurie
#   URL de l'image : https://www.olfastory.com/sites/www.olfastory.com/files/styles/300x300/public/somei-yoshino.jpg?itok=4uadijJo
#   Concentration : Eau de cologne
#   Facettes : Fruitée
#   Date de création : 2015
#   Parfumeurs : Inconnu
#   Titre de description : Inconnu
#   Texte de description :
#   Notes de tête : Bergamote;Note verte
#   Notes de cœur : Rose;Pêche;Jasmin;Magnolia;Corbeille de fruits
#   Notes de fond : Patchouli;Vanille;Santal;Violette
# --------------------------------------------------
# Parfum trouvé :
#   Nom : Corsica Furiosa
#   URL : https://www.olfastory.com/parfum/corsica-furiosa
#   Marque : Parfum d'Empire
#   Type : Eau de parfum
#   Année : 2014
#   Genre : Mixte
#   Famille olfactive : Boisée
#   URL de l'image : https://www.olfastory.com/sites/www.olfastory.com/files/styles/300x300/public/corsica-furiosa.jpg?itok=78ic_Jf7
#   Concentration : Eau de parfum
#   Facettes : Verte
#   Date de création : 2014
#   Parfumeurs : Marc-Antoine Corticchiato
#   Titre de description : Corsica Furiosa, la Corse et rien d’autre
#   Texte de description : Corsica Furiosa, la Corse et rien d’autreMarc-Antoine Corticchiato, parfumeur de la marque Parfum Empire, est natif de Corse, plus exactement du petit village de Cuttoli-Corticchiato. À travers « Corsica Furiosa », Marc-Antoine a souhaité rendre à sa terre, un véritable hommage olfactif.
#   Notes de tête : Pamplemousse;Bergamote;Citron
#   Notes de cœur : Jasmin;Cassis;Galbanum;Lentisque;Feuille de tomate
#   Notes de fond : Mousse de chêne;Bois ambrés;Iso E Super;Muscs blancs;Pin
# --------------------------------------------------
# Parfum trouvé :
#   Nom : Vânira Moorea
#   URL : https://www.olfastory.com/parfum/vanira-moorea
#   Marque : Berdoues
#   Type : Eau de parfum
#   Année : 2016
#   Genre : Mixte
#   Famille olfactive : Fleurie
#   URL de l'image : https://www.olfastory.com/sites/www.olfastory.com/files/styles/300x300/public/vanira-moorea.jpg?itok=xBzshuBk
#   Concentration : Eau de parfum
#   Facettes : Ambrée
#   Date de création : 2016
#   Parfumeurs : Inconnu
#   Titre de description : Inconnu
#   Texte de description : Pierre Berdoues dit un jour : « Un parfum c'est comme un accord musical, l'harmonie résulte d'une composition parfaite de notes basses et aiguës. Un parfumeur, c'est un compositeur, qui joue avec les essences comme un musicien joue avec les notes. »
#   Notes de tête : Mandarine;Orange;Citron
#   Notes de cœur : Fleur d'Oranger;Néroli;Petitgrain
#   Notes de fond : Benjoin;Vanille;Coumarine;Muscs blancs
# --------------------------------------------------
# Parfum trouvé :
#   Nom : Muguet Porcelaine
#   URL : https://www.olfastory.com/parfum/muguet-porcelaine
#   Marque : Hermès
#   Type : Eau de toilette
#   Année : 2016
#   Genre : Mixte
#   Famille olfactive : Fleurie
#   URL de l'image : https://www.olfastory.com/sites/www.olfastory.com/files/styles/300x300/public/muguet-porcelaine.jpg?itok=mS5vbBhF
#   Concentration : Eau de toilette
#   Facettes : Verte
#   Date de création : 2016
#   Parfumeurs : Jean-Claude Ellena
#   Titre de description : Inconnu
#   Texte de description : Si le muguet est très souvent contenu dans les parfums, il est très rare que cette petite fleur blanche emblématique de notre fête du travail soit placée en avant. Elle sert le plus souvent à apporter de la légèreté aux parfums qui en contiennent mais n'occupe que de très rares fois le poste de star des recettes olfactives.
#   Notes de tête : Bergamote;Note verte
#   Notes de cœur : Néroli;Hédione;Poire;Muguet;Note aqueuse
#   Notes de fond : Muscs blancs;Note animale
# --------------------------------------------------
#
# Scraping https://www.olfastory.com/parfums/mixte (Page 34)
#
# === Parfums de la catégorie : https://www.olfastory.com/parfums/mixte?page=33 (Page 34) ===
#
# Parfum trouvé :
#   Nom : Iris Harmonique
#   URL : https://www.olfastory.com/parfum/iris-harmonique
#   Marque : Givenchy
#   Type : Eau de parfum
#   Année : 2016
#   Genre : Mixte
#   Famille olfactive : Boisée
#   URL de l'image : https://www.olfastory.com/sites/www.olfastory.com/files/styles/300x300/public/iris-harmonique-givenchy.jpg?itok=VH8RYO7z
#   Concentration : Eau de parfum
#   Facettes : Ambrée;Poudrée
#   Date de création : 2016
#   Parfumeurs : Inconnu
#   Titre de description : Inconnu
#   Texte de description : La maison Givenchy élabore depuis plusieurs années des parfums appartenant à une collection nommée L’Atelier. Ces derniers sont confectionnés à base des plus belles matières premières et incarnent la quintessence du style Givenchy. Chacun d'entre eux matérialise une personnalité et rend hommage à la noblesse de la Haute Parfumerie.
#   Notes de tête : Angélique
#   Notes de cœur : Coumarine;Ylang-Ylang
#   Notes de fond : Bois ambrés;Santal;Iris;Fève tonka;Immortelle;Cèdre
# --------------------------------------------------
# Parfum trouvé :
#   Nom : Bergamote Soleil
#   URL : https://www.olfastory.com/parfum/bergamote-soleil
#   Marque : Atelier Cologne
#   Type : Eau de parfum
#   Année : 2016
#   Genre : Mixte
#   Famille olfactive : Hespéridée
#   URL de l'image : https://www.olfastory.com/sites/www.olfastory.com/files/styles/300x300/public/bergamote-soleil-atelier-cologne.jpg?itok=ye9SruXV
#   Concentration : Eau de parfum
#   Facettes : Verte
#   Date de création : 2016
#   Parfumeurs : Jérôme Epinette
#   Titre de description : Inconnu
#   Texte de description : C'est une histoire d'amour qui a conduit Christophe Cervasel et Sylvie Ganter à créer leur propre maison de parfumerie nommée Atelier Cologne. Ensemble, ils décidèrent de rendre grâce aux Eaux de Cologne, des fragrances parfumées considérées comme étant les prémices de notre parfumerie moderne.
#   Notes de tête : Pamplemousse;Bergamote;Citron;Bigarade
#   Notes de cœur : Jasmin;Note verte;Hédione
#   Notes de fond : Muscs blancs;Evernyl;Vanilline;Notes solaires
# --------------------------------------------------
# Parfum trouvé :
#   Nom : Blu Mediterraneo Cedro di Taormina
#   URL : https://www.olfastory.com/parfum/blu-mediterraneo-cedro-di-taormina
#   Marque : Acqua Di Parma
#   Type : Eau de toilette
#   Année : 2016
#   Genre : Mixte
#   Famille olfactive : Hespéridée
#   URL de l'image : https://www.olfastory.com/sites/www.olfastory.com/files/styles/300x300/public/blu-mediterraneo-cedro-di-taormina.jpg?itok=WbEvGyD1
#   Concentration : Eau de toilette
#   Facettes : Inconnu
#   Date de création : 2016
#   Parfumeurs : François Demachy
#   Titre de description : Inconnu
#   Texte de description : La collection de parfums Blu Mediterraneo de la maison Acqua Di Parma rend hommage, comme son nom l'indique, au bassin méditerranéen. À ce titre, elle contient de multiples fragrances renfermant l'énergie marine, l'éclat du soleil et les couleurs des lieux les plus emblématiques de la Méditerranée.
#   Notes de tête : Mandarine;Menthe;Bergamote;Orange;Citron;Petitgrain;Basilic;Cédrat
#   Notes de cœur : Hédione;Thé
#   Notes de fond : Vétiver;Muscs blancs;Cèdre;Ciste;Evernyl
# --------------------------------------------------
# Parfum trouvé :
#   Nom : Bucoliques de Provence
#   URL : https://www.olfastory.com/parfum/bucoliques-de-provence
#   Marque : L'Artisan Parfumeur
#   Type : Eau de parfum
#   Année : 2016
#   Genre : Mixte
#   Famille olfactive : Aromatique
#   URL de l'image : https://www.olfastory.com/sites/www.olfastory.com/files/styles/300x300/public/bucoliques-de-provence-artisan-parfumeur.jpg?itok=oZqTz8v3
#   Concentration : Eau de parfum
#   Facettes : Poudrée;Ambrée
#   Date de création : 2016
#   Parfumeurs : Fabrice Pellegrin
#   Titre de description : Inconnu
#   Texte de description : L’Artisan Parfumeur est une marque au sein de laquelle chaque parfum représente un voyage à part entière. Chaque jus y est créé avec passion et finesse tout en étant le fruit d'un savoir-faire artisanal hors pair.
#   Notes de tête : Lavande;Bergamote
#   Notes de cœur : Fleur d'Oranger;Jasmin;Genièvre
#   Notes de fond : Benjoin;Vanille;Coumarine;Muscs blancs;Iris
# --------------------------------------------------
# Parfum trouvé :
#   Nom : Ambre Eternel
#   URL : https://www.olfastory.com/parfum/ambre-eternel
#   Marque : Guerlain
#   Type : Eau de parfum
#   Année : 2016
#   Genre : Mixte
#   Famille olfactive : Orientale
#   URL de l'image : https://www.olfastory.com/sites/www.olfastory.com/files/styles/300x300/public/guerlain-ambre-eternel.jpg?itok=wmi0xfmy
#   Concentration : Eau de parfum
#   Facettes : Poudrée;Cuir
#   Date de création : 2016
#   Parfumeurs : Thierry Wasser
#   Titre de description : Inconnu
#   Texte de description : Depuis toujours, Guerlain voit en l’Orient une terre capable de faire naître un fantastique élan de créativité. Aussi, c'est en toute logique que l'enseigne a souhaitée rendre hommage à cette partie du globe ayant su faire naître ses plus beaux chefs-d’œuvre.
#   Notes de tête : Bergamote
#   Notes de cœur : Cardamome;Fleur d'Oranger;Coriandre
#   Notes de fond : Patchouli;Iris;Ambre gris;Castoreum;Carotte
# --------------------------------------------------
#
# Base de données sauvegardée dans 'parfums.csv' et 'parfums.xlsx' avec 2051 parfums.

# %%
df.head()
# Out:
#                     name                                        perfume_url  \
# 0  Acqua di Giò Profondo  https://www.olfastory.com/parfum/acqua-di-gio-...
# 1    L.12.12 Silver Grey  https://www.olfastory.com/parfum/l1212-silver-...
# 2               Original          https://www.olfastory.com/parfum/original
# 3          A*Men Stellar      https://www.olfastory.com/parfum/amen-stellar
# 4            Code Elixir       https://www.olfastory.com/parfum/code-elixir
#
#             brand             type  year gender      family  \
# 0          Armani  Eau de toilette  2025  Homme  Aromatique
# 1         Lacoste    Eau de parfum  2025  Homme     Fougère
# 2         Lacoste          Extrait  2025  Homme     Fougère
# 3  Thierry Mugler    Eau de parfum  2025  Homme      Boisée
# 4          Armani    Eau de parfum  2025  Homme   Orientale
#
#                                            image_url    concentration  \
# 0  https://www.olfastory.com/sites/www.olfastory....  Eau de toilette
# 1  https://www.olfastory.com/sites/www.olfastory....    Eau de parfum
# 2  https://www.olfastory.com/sites/www.olfastory....          Extrait
# 3  https://www.olfastory.com/sites/www.olfastory....    Eau de parfum
# 4  https://www.olfastory.com/sites/www.olfastory....    Eau de parfum
#
#                facettes date_creation                     parfumeurs  \
# 0                Marine          2025               Alberto Morillas
# 1                Boisée          2025                Bruno Jovanovic
# 2         Ambrée;Epicée          2025                        Inconnu
# 3  Aromatique;Gourmande          2025  Jacques Huclier;Louise Turner
# 4    Ambrée;Cuir;Epicée          2025                        Inconnu
#
#                                    description_title  \
# 0                             Présentation du parfum
# 1  Présentation du parfum Lacoste L.12.12 Silver ...
# 2         Lacoste Original Parfum – Carte d’identité
# 3  A*Men Stellar : la nouvelle détonation gourman...
# 4  Armani Code Elixir : la nouvelle décharge d’in...
#
#                                     description_text  \
# 0  Présentation du parfumImmersion dans le bleu p...
# 1  Présentation du parfum Lacoste L.12.12 Silver ...
# 2  Lacoste Original Parfum – Carte d’identitéLe c...
# 3  A*Men Stellar : la nouvelle détonation gourman...
# 4  Armani Code Elixir : la nouvelle décharge d’in...
#
#                                 notes_tete  \
# 0  Cardamome;Citron;Mandarine;Pamplemousse
# 1                         Encens;Mandarine
# 2               Bergamote;Cardamome;Poivre
# 3                        Bergamote;Lavande
# 4                                Mandarine
#
#                                  notes_coeur                   notes_fond
# 0  Cyprès;Lavandin;Note marine;Sauge sclarée               Musc;Patchouli
# 1                           Géranium;Lavande             Ambroxan;Vétiver
# 2             Lavande;Lavandin;Sauge sclarée  Fève tonka;Patchouli;Santal
# 3                                   Pistache                Notes Boisées
# 4                                       Cuir                   Fève tonka

# %%
df_homme = df[df["gender"].str.capitalize() == "Homme"]
df_femme = df[df["gender"].str.capitalize() == "Femme"]
df_mixte = df[df["gender"].str.capitalize() == "Mixte"]

    # Print summary of filtered data
print(f"Nombre de parfums pour Homme : {len(df_homme)}")
print(f"Nombre de parfums pour Femme : {len(df_femme)}")
print(f"Nombre de parfums pour Mixte : {len(df_mixte)}")

    # Create new Excel file with separate sheets
with pd.ExcelWriter("parfums_par_genre.xlsx", engine="openpyxl") as writer:
    df_homme.to_excel(writer, sheet_name="Homme", index=False)
    df_femme.to_excel(writer, sheet_name="Femme", index=False)
    df_mixte.to_excel(writer, sheet_name="Mixte", index=False)
# Out:
# Nombre de parfums pour Homme : 582
# Nombre de parfums pour Femme : 1192
# Nombre de parfums pour Mixte : 277

# %%
df.to_json("parfums.json", orient="records", indent=2)
df_homme.to_json("parfums_homme.json", orient="records", indent=2)
df_femme.to_json("parfums_femme.json", orient="records", indent=2)
df_mixte.to_json("parfums_mixte.json", orient="records", indent=2)

# %%
df.family.unique()
# Out:
# array(['Aromatique', 'Fougère', 'Boisée', 'Orientale', 'Hespéridée',
#        'Fleurie', 'Chyprée', ''], dtype=object)

# %%
df.columns
# Out:
# Index(['name', 'perfume_url', 'brand', 'type', 'year', 'gender', 'family',
#        'image_url', 'concentration', 'facettes', 'date_creation', 'parfumeurs',
#        'description_title', 'description_text', 'notes_tete', 'notes_coeur',
#        'notes_fond'],
#       dtype='object')

# %%
unique_scents = set(df[['notes_tete', 'notes_coeur', 'notes_fond']]
                    .stack()  # Stack to combine all values into a single Series
                    .str.split(';', expand=True)  # Split by semicolon
                    .stack()  # Stack again to get individual scents
                    .str.strip()  # Remove any leading/trailing whitespace
                    .unique())  # Get unique values

# Convert to list if needed
unique_scents = list(unique_scents)
print(unique_scents)
# Out:
# ['Ambre', "Mousse d'arbre", 'Fleur de Citronnier', 'Banane', 'Baies de genévrier', 'Bigarade', 'Orchidée', 'Cascarille', 'Muscs blancs', 'Gentiane', 'Note aqueuse', "Feuilles d'Ajonc", 'Bergamote', 'Epices', 'Framboise', 'Glycine', 'Champagne Rosé', 'Evernyl', 'Gardénia', 'Gurjan', 'Notes fumées', 'Orange', 'Caramel', 'Mûre', 'Mangue', 'Eau de Rose', 'Tubéreuse', 'Akigalawood®', 'Tabac', 'Oliban', 'Cuir', 'Cannabis', 'Cyclamen', 'Estragon', 'Laurier', 'Pain', 'Poivre', 'Palo Santo', 'Silex', 'Thym', 'Amande amère', 'Immortelle', 'Nashi pear', 'Safran', 'Petitgrain', 'Dahlia', 'Freesia', 'Macchiato', 'Piña Colada', "Fleur d'Oranger", 'Buchu', 'Dragée', 'Cyprès', 'Hédione', 'Cerise', 'Ambroxan', "Cire d'abeille", 'Popcorn', 'Notes de Pluie', 'Poivre Rose', 'Chocolat', 'Baies roses', 'Eau de mer', 'Concombre', 'Praline', 'Ebene', 'Romarin', 'Galbanum', 'Maninka', 'Cypriol', 'Accord aromatique', 'Hibiscus', 'Poudre à canon', 'Bellini', 'Costus', 'Fève tonka', 'Bois', 'Cassie', 'Algue', 'Pin', 'Cannelle', 'Ambrette', 'Figuier', 'Nénuphar', 'Notes balsamiques', 'Eucalyptus', 'Ylang-Ylang', 'Narcisse', 'Carvi', 'Lait chaud', 'Iris', "Fruits d'eau", 'Amyris', 'Myrtille', 'Citronnelle', 'Orange Verte', 'Gingembre', 'Karo karoundé', 'Ozone', 'Basilic', 'Vanille', 'Cranberry', 'Notes Rosées', 'Notes suaves', 'Hortensia', 'Trèfle', 'Mojito', 'Notes orientales', 'Pivoine', 'Néroli', 'Piment', 'Châtaigne', 'Fir balsam', 'Myrrhe', 'Bambou', 'Magnolia', 'Pistache', 'Amande', 'Reine de la Nuit', 'Cédrat', 'Grenade', 'Osmanthus', 'Anis', 'Pavot', 'Musc', 'Lavande', 'Fraise', 'Champaca', 'Macaron', 'Cumin', 'Fleurs Blanches', 'Jasmin', 'Marjolaine', 'Pittosporum', 'Badiane', 'Coing', 'férule gommeuse', 'Bois de Cachemire', 'Daim', 'Dihydromyrcénol', 'Clémentine', 'Sable Chaud', 'Musc tonkin', 'Bois de gaiac', 'Pure Malt', 'bougainvillier', 'Céleri', 'Pitaya', 'Lemongrass', 'Noisette', 'Coumarine', 'Fruits secs', 'Ciste', 'Pois de senteur', 'Vanilline', 'Hysope', 'Patchouli', 'Tiaré', 'Cognac', 'notes terreuses', 'Vétiver', 'Notes Minérales', 'Sésame', 'Acajou', 'Aneth', 'MUGU', 'Notes solaires', 'Feuille de mandarinier', 'Truffe', 'Lotus', 'Limette', 'Pastèque', 'Rhubarbe', 'Violette', 'Raisin', 'Héliotrope', 'Lavandin', 'Dattes', 'son de blé', 'Poire', 'Agrumes', 'Ambre gris', 'Frangipanier', 'Bois ambrés', 'Baume Pérou', 'Cardamome', 'Curcuma', 'Inconnu', 'Aubépine', 'Feuille de tomate', 'Géranium', 'Sel de mer', 'Note Fruitée', 'Guimauve', 'Ananas', 'Datura', 'Pruneau', 'Fruit de la passion', 'Mirabilis', 'Riz', 'Mimosa', 'Aldéhydes', 'Paradisone', 'Iso E Super', 'Abricot', 'Mousse de chêne', 'Camomille romaine', 'Fleurs Exotiques', 'Sucre', 'Fleurs de palmier', 'Cassis', 'Macis', 'Cappuccino', 'Myrte', 'Lierre', 'Lilas', 'Oxyde de rose', 'Papaye', 'Kiwi', 'Groseille', 'Réglisse', 'Fruits Rouges', 'Mirabelle', 'Mangoustan', 'Calamus', 'Tulipe', 'Tagète', 'Noix de coco', 'Résine', 'Prune', 'Pêche', 'Feuille de vigne', 'Sauge sclarée', 'Tangerine', 'Citron', 'Chêne', 'Girofle', 'Civette', 'Notes poudrées', 'Litchi', 'Pamplemousse', 'Genêt', 'Lie de vin', 'Lys', 'Quisqualier', 'Thé Noir', 'Pomme', 'Coriandre', 'Thé', 'Corbeille de fruits', 'Belle de Nuit', 'Styrax', 'Noix de muscade', 'Chèvrefeuille', 'Bois de rose', 'Orcanox', 'Notes Boisées', 'Dulce de Leche', 'Armoise', 'Barbe à papa', 'Verveine', 'Castoreum', 'Sel', 'Fenouil', 'Angélique', 'undefined', 'Feuille de violette', 'Opopanax', 'Figue', 'Kumquat', 'Crème fouettée', 'Bouleau', 'Jonquille', 'Accord herbe de bison', 'Ginseng', 'agathosma', 'Note marine', 'Elemi', 'Menthe', 'Nectarine', 'Bois de Hêtre', 'Encens', 'Fleur de Cerisier', 'Rose', 'Notes fleuries', 'Baies de Goji', 'Davana', 'Absinthe', 'Limoncello', 'Animalis', 'Oud', 'Baume Tolu', 'Cèdre', 'Cannellier Feuille', 'Seringa', 'Eau de vie', 'Lentisque', 'Cashmeran', 'Genièvre', 'Oeillet', 'Foin', 'Fruits Exotiques', 'Muguet', 'Note animale', 'Champagne', 'Santal', 'Yuzu', "Lait d'Amande", 'Sorbet', 'Note verte', 'Melon', 'Caviar ...

# %%
len(unique_scents)
# Out:
# 336

# %%
scent_counts = (df[['notes_tete', 'notes_coeur', 'notes_fond']]
                .stack()  # Combine all values into a single Series
                .str.split(';', expand=True)  # Split by semicolon
                .stack()  # Get individual scents
                .str.strip()  # Remove whitespace
                .value_counts()  # Count occurrences of each scent
                )

# Convert to a sorted list of (scent, count) tuples (optional)
sorted_scents = scent_counts.reset_index().values.tolist()
print(sorted_scents)
# Out:
# [['Bergamote', 712], ['Vanille', 690], ['Jasmin', 679], ['Patchouli', 653], ['Rose', 642], ['Muscs blancs', 547], ['Cèdre', 487], ['Mandarine', 443], ['Santal', 440], ['Citron', 383], ['Vétiver', 355], ["Fleur d'Oranger", 347], ['Ambre', 272], ['Iris', 266], ['Fève tonka', 251], ['Musc', 250], ['Lavande', 240], ['Pamplemousse', 198], ['Néroli', 173], ['Orange', 170], ['Bois ambrés', 168], ['Pêche', 163], ['Cardamome', 161], ['Poire', 153], ['Ylang-Ylang', 147], ['Cassis', 145], ['Mousse de chêne', 144], ['Benjoin', 142], ['Géranium', 135], ['Poivre noir', 133], ['Menthe', 131], ['Tubéreuse', 131], ['Note verte', 130], ['Cuir', 125], ['Violette', 123], ['Sauge sclarée', 122], ['Gingembre', 122], ['Muguet', 122], ['Pomme', 120], ['Pivoine', 116], ['Framboise', 111], ['Notes Boisées', 110], ['Baies roses', 108], ['Note marine', 105], ['Cannelle', 103], ['Aldéhydes', 101], ['Caramel', 101], ['Encens', 99], ['Poivre Rose', 94], ['Labdanum', 91], ['Héliotrope', 91], ['Freesia', 88], ['Coriandre', 80], ['Coumarine', 77], ['Feuille de violette', 72], ['Thé', 69], ['Basilic', 69], ['Noix de muscade', 66], ['Magnolia', 66], ['Ambre gris', 63], ['Girofle', 62], ['Petitgrain', 62], ['Cashmeran', 61], ['Amande', 56], ['Romarin', 54], ['Hédione', 54], ['Gardénia', 53], ['Osmanthus', 53], ['Miel', 53], ['Bois de Cachemire', 52], ['Réglisse', 52], ['Poivre', 51], ['Galbanum', 50], ['Dihydromyrcénol', 47], ['Evernyl', 45], ['Cyprès', 45], ['Prune', 44], ['Ambroxan', 44], ['Safran', 44], ['Ambrette', 44], ['Tabac', 44], ['Noix de coco', 43], ['Oeillet', 43], ['Bois de gaiac', 43], ['Cerise', 42], ['Café', 42], ['Anis', 42], ['Vanilline', 42], ['Ananas', 42], ['Inconnu', 42], ['Cacao', 41], ['Praline', 40], ['Litchi', 40], ['Genièvre', 40], ["Mousse d'arbre", 38], ['Fraise', 37], ['Lys', 36], ['Myrrhe', 35], ['Jacinthe', 34], ['Amande amère', 34], ['Oud', 32], ['Agrumes', 32], ['Figue', 32], ['Armoise', 31], ['Iso E Super', 30], ['Ciste', 30], ['Mûre', 30], ['Bois', 29], ['Frangipanier', 29], ['Rhubarbe', 29], ['Mimosa', 29], ['Elemi', 28], ['Narcisse', 26], ['Bourgeon de cassis', 26], ['Fruit de la passion', 25], ['Thym', 25], ['Notes fleuries', 25], ['Chèvrefeuille', 24], ['Cumin', 23], ['Tiaré', 23], ['Limette', 23], ['Abricot', 23], ['Fruits Rouges', 23], ['Notes solaires', 22], ['Pin', 22], ['Lilas', 21], ['Lait chaud', 21], ['Bigarade', 20], ['Badiane', 20], ['Mangue', 20], ['Fleurs Blanches', 20], ['Melon', 20], ['Daim', 19], ['Bois de rose', 19], ['Rhum', 19], ['Yuzu', 18], ['Verveine', 18], ['Epices', 18], ['Styrax', 18], ['Cyclamen', 18], ['Noisette', 16], ['Chocolat', 16], ['Ozone', 16], ['Oliban', 16], ['Civette', 16], ['Orchidée', 16], ['Piment', 15], ['Note Fruitée', 15], ['Angélique', 14], ['Fir balsam', 14], ['Immortelle', 14], ['Cédrat', 14], ['Opopanax', 13], ['Groseille', 13], ['Baume Tolu', 13], ['Laurier', 12], ['Lentisque', 12], ['Lotus', 12], ['Castoreum', 12], ['Estragon', 12], ['Thé Noir', 11], ['Pistache', 11], ['Notes Minérales', 10], ['Aubépine', 10], ['Figuier', 10], ['Maté', 10], ['Davana', 10], ['Notes poudrées', 10], ['Sel de mer', 9], ['Carvi', 9], ['Bouleau', 9], ['Camomille romaine', 9], ['Lavandin', 9], ['Cypriol', 9], ['Grenade', 9], ['Baume Pérou', 9], ['Eucalyptus', 9], ['Datura', 9], ['Akigalawood®', 9], ['Sel', 9], ['Feuille de tomate', 8], ['Musc tonkin', 8], ['Résine', 8], ['Fruits Exotiques', 7], ['Sorbet', 7], ['Myrtille', 7], ['Foin', 7], ['Genêt', 7], ['Shiso', 7], ['Maninka', 7], ['Chêne', 7], ['Raisin', 7], ['Pastèque', 7], ['Absinthe', 6], ['Notes fumées', 6], ['Jonquille', 6], ['Eau de Rose', 6], ['Note animale', 6], ['Carotte', 6], ['Sésame', 6], ["Cire d'abeille", 5], ['Myrte', 5], ['Cade', 5], ['Cassie', 5], ['Pruneau', 5], ['Coing', 5], ['Algue', 5], ['Amyris', 5], ['Fleur de Cerisier', 5], ["Lait d'Amande", 5], ['Tagète', 5], ['Notes orientales', 4], ['Sucre', 4], ['Pitaya', 4], ['Eau de mer', 4], ['Pois de senteur', 4], ['Corbeille de fruits', 4], ['Hibiscus', 4], ['Note aqueuse', 4], ['Mi ...

# %%
# Or, print as a DataFrame with scents and counts
print(scent_counts.reset_index(name='count').rename(columns={'index': 'scent'}))
# Out:
#                  scent  count
# 0            Bergamote    712
# 1              Vanille    690
# 2               Jasmin    679
# 3            Patchouli    653
# 4                 Rose    642
# ..                 ...    ...
# 331  Fleurs de palmier      1
# 332         Paradisone      1
# 333          Hortensia      1
# 334            Calamus      1
# 335         Cascarille      1
#
# [336 rows x 2 columns]
